# %%
import os
import pandas as pd

# This script processes CSV files containing neighbor entries for different attributes,
# extracts unique neighbors, and saves them to separate text files for each attribute.

# Directory containing the input CSV files
directory = 'splits'
# Directory where the output text files will be saved
output_directory = 'faiss_index'

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# List of attributes to process
attributes = ['bioActivity', 'collectionSite', 'collectionSpecie', 'collectionType', 'name']

for attribute in attributes:
    # Initialize a set to store unique neighbor entries
    unique_neighbors = set()

    # Iterate over all files in the directory
    for filename in os.listdir(directory):
        if filename.startswith(f"test_doi_{attribute}") or filename.startswith(f"train_doi_{attribute}"):
            filepath = os.path.join(directory, filename)
            # Read the CSV file
            df = pd.read_csv(filepath)
            # Add unique neighbor entries to the set
            unique_neighbors.update(df['neighbor'].unique())

    # Save the unique neighbors to a text file
    with open(os.path.join(output_directory, f'unique_{attribute}.txt'), 'w') as f:
        for neighbor in sorted(unique_neighbors):
            f.write(f"{neighbor}\n")

# %%
#create faiss indexes
import os
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Set your OpenAI API key
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the text files
input_directory = 'faiss_index'
output_directory = 'faiss_index_trained'

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Iterate over all text files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.txt'):
        filepath = os.path.join(input_directory, filename)
        
        # Read the text file and create Document objects
        entities = []
        with open(filepath, 'r') as f:
            for line in f:
                text = line.strip()
                doc = Document(page_content=text, metadata={'text': text})
                entities.append(doc)
        
        # Create FAISS index from documents
        faiss_index = FAISS.from_documents(entities, embeddings)
        
        # Save the FAISS index locally
        index_path = os.path.join(output_directory, f'{filename}.index')
        faiss_index.save_local(index_path)

print("FAISS indices have been created and saved.")
# Out:
# FAISS indices have been created and saved.

# %%
#test Faiss indexes
import os
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set your OpenAI API key
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

# Mapping from number to attribute
attribute_mapping = {
    1: 'collectionSpecie',
    2: 'collectionSite',
    3: 'bioActivity',
    4: 'name',
    5: 'collectionType'
}

def load_faiss_index(attribute_number):
    attribute = attribute_mapping.get(attribute_number)
    if not attribute:
        raise ValueError(f"Invalid attribute number: {attribute_number}")
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index for attribute '{attribute}' not found.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(attribute_number, query, top_k=5):
    faiss_index = load_faiss_index(attribute_number)
    docs_with_score = faiss_index.similarity_search_with_score(query, top_k=top_k)
    return docs_with_score

# Example usage
attribute_number = 2  # Change this to the attribute number you want to search (1 to 5)
query = "test"  # Change this to your query string

try:
    results = similarity_search(attribute_number, query)
    for doc, score in results:
        print(f"Document: {doc.page_content}, Score: {score}")
except (FileNotFoundError, ValueError) as e:
    print(e)

# %%
#Updated and Optimized workflow to account for multiple simsearch results being inserted to the file (for hits@k != 1)
import os
import ast
import csv
import re
import logging
import shutil
from tqdm import tqdm
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set your OpenAI API key
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

def load_faiss_index(attribute):
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index directory for attribute '{attribute}' not found.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(faiss_index, query, top_k):
    docs_with_score = faiss_index.similarity_search_with_score(query, k=top_k)
    return docs_with_score

def clean_restored_field(restored_str):
    # Remove any leading/trailing whitespace and ensure proper list format
    restored_str = restored_str.strip()
    if not (restored_str.startswith('[') and restored_str.endswith(']')):
        restored_str = f"[{restored_str}]"
    return restored_str

def process_row(row, faiss_index, attribute, top_k):
    try:
        restored_str = clean_restored_field(row['restored'])
        restored = ast.literal_eval(restored_str)
        if len(restored) > 1 and isinstance(restored[1], list):
            restored[1] = [str(item) for item in restored[1]]
            query = ' '.join(restored[1])
            docs_with_score = similarity_search(faiss_index, query, top_k)
            if docs_with_score:
                old_value = row['restored']
                similar_entries = ', '.join([doc.page_content for doc, _ in docs_with_score])
                new_restored_value = [restored[0], [similar_entries]]
                row['restored'] = str(new_restored_value)
                logging.info(f"changed {old_value} to {new_restored_value} in row {row['true']}")
    except (ValueError, SyntaxError, TypeError) as e:
        logging.error(f"Error parsing restored field in row {row}: {e}")
    return row

def update_restored_with_similarity_search(file_path, attribute, top_k):
    backup_file_path = file_path + '.bak'
    shutil.copy(file_path, backup_file_path)
    
    try:
        faiss_index = load_faiss_index(attribute)
    except FileNotFoundError as e:
        logging.error(e)
        return

    temp_file = file_path + '.temp'
    batch_size = 100  # Adjust this based on your available memory

    with open(file_path, 'r', newline='', encoding='utf-8') as infile, \
         open(temp_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()

        batch = []
        for row in tqdm(reader, desc=f"Processing rows in {os.path.basename(file_path)}"):
            batch.append(row)
            if len(batch) >= batch_size:
                processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
                writer.writerows(processed_batch)
                batch = []

        if batch:
            processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
            writer.writerows(processed_batch)

    os.replace(temp_file, file_path)

def process_files_for_similarity_search(directory, attribute, top_k):
    pattern = re.compile(rf'llm_results_gpt4_0.8_doi_{attribute}_\d+_\d+(?:st|nd|rd|th)\.csv')
    files = [f for f in os.listdir(directory) if pattern.match(f)]

    for filename in tqdm(files, desc="Processing files"):
        file_path = os.path.join(directory, filename)
        logging.info(f"Processing file: {filename} with attribute: {attribute}")
        update_restored_with_similarity_search(file_path, attribute, top_k)

# Process all files for each attribute
directory = 'results/LLM_corr_k_full/'
attributes_and_k = {
    #'collectionSpecie': 50,
    #'collectionSite': 20,
    #'bioActivity': 5,
    'name': 50,
    #'collectionType': 1
}

for attribute, top_k in attributes_and_k.items():
    logging.info(f"Processing attribute: {attribute} with top_k: {top_k}")
    process_files_for_similarity_search(directory, attribute, top_k)

# %%
# for finetuned model. collectionSite 0 1st
import os
import ast
import csv
import re
import logging
import shutil
from tqdm import tqdm
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set your OpenAI API key
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the 'OPENAI_API_KEY' environment variable.")

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

def load_faiss_index(attribute):
    """
    Load the FAISS index for a given attribute.

    Parameters:
    - attribute (str): The attribute name (e.g., 'collectionSite').

    Returns:
    - FAISS: The loaded FAISS index object.
    """
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index file for attribute '{attribute}' not found at {index_path}.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(faiss_index, query, top_k):
    """
    Perform a similarity search using the FAISS index.

    Parameters:
    - faiss_index (FAISS): The FAISS index object.
    - query (str): The query string.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - list of tuples: Each tuple contains (Document, score).
    """
    docs_with_score = faiss_index.similarity_search_with_score(query, k=top_k)
    return docs_with_score

def clean_restored_field(restored_str):
    """
    Clean and ensure the 'restored' field is in proper list format.

    Parameters:
    - restored_str (str): The string representation of the 'restored' field.

    Returns:
    - str: Cleaned string in list format.
    """
    restored_str = restored_str.strip()
    if not (restored_str.startswith('[') and restored_str.endswith(']')):
        restored_str = f"[{restored_str}]"
    return restored_str

def process_row(row, faiss_index, attribute, top_k):
    """
    Process a single row by performing similarity search and updating the 'restored' field.

    Parameters:
    - row (dict): The CSV row as a dictionary.
    - faiss_index (FAISS): The FAISS index object.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - dict: The updated row.
    """
    try:
        restored_str = clean_restored_field(row['restored'])
        restored = ast.literal_eval(restored_str)
        # Check if 'restored' has the expected structure
        if isinstance(restored, list) and len(restored) == 2 and isinstance(restored[1], list):
            # Convert all predicted values to strings
            restored[1] = [str(item) for item in restored[1]]
            # Create a query by joining the predicted values
            query = ' '.join(restored[1])
            # Perform similarity search
            docs_with_score = similarity_search(faiss_index, query, top_k)
            if docs_with_score:
                # Extract the most similar entries
                similar_entries = [doc.page_content for doc, _ in docs_with_score]
                # Update the 'restored' field with similar entries
                new_restored_value = [restored[0], similar_entries]
                old_value = row['restored']
                row['restored'] = str(new_restored_value)
                logging.info(f"Updated 'restored' from {old_value} to {new_restored_value} for DOI {row['true']}")
        else:
            logging.warning(f"Unexpected 'restored' format in row: {row}")
    except (ValueError, SyntaxError, TypeError) as e:
        logging.error(f"Error parsing 'restored' field in row {row}: {e}")
    return row

def update_restored_with_similarity_search(file_path, attribute, top_k):
    """
    Update the 'restored' field in the CSV file using similarity search.

    Parameters:
    - file_path (str): Path to the input CSV file.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    backup_file_path = file_path + '.bak'
    shutil.copy(file_path, backup_file_path)
    logging.info(f"Backup created at {backup_file_path}")

    try:
        faiss_index = load_faiss_index(attribute)
    except FileNotFoundError as e:
        logging.error(e)
        return

    temp_file = file_path + '.temp'
    batch_size = 100  # Adjust this based on your available memory

    with open(file_path, 'r', newline='', encoding='utf-8') as infile, \
         open(temp_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()

        batch = []
        for row in tqdm(reader, desc=f"Processing rows in {os.path.basename(file_path)}"):
            batch.append(row)
            if len(batch) >= batch_size:
                processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
                writer.writerows(processed_batch)
                batch = []

        if batch:
            processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
            writer.writerows(processed_batch)

    os.replace(temp_file, file_path)
    logging.info(f"Updated file saved at {file_path}")

def process_files_for_similarity_search(directory, attribute, top_k):
    """
    Process all relevant CSV files in the specified directory for similarity search.

    Parameters:
    - directory (str): Directory containing the CSV files.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    # Updated pattern to match the new filename format
    pattern = re.compile(rf'llm_results_ft_4o_0\.8_doi_{re.escape(attribute)}_0_1st\.csv')
    files = [f for f in os.listdir(directory) if pattern.match(f)]

    if not files:
        logging.warning(f"No files found matching pattern for attribute '{attribute}' in directory '{directory}'.")
        return

    for filename in tqdm(files, desc="Processing files"):
        file_path = os.path.join(directory, filename)
        logging.info(f"Processing file: {filename} for attribute: {attribute}")
        update_restored_with_similarity_search(file_path, attribute, top_k)

# Process only the 'collectionSite' attribute with top_k=20
directory = 'llm_ft_results'
attributes_and_k = {
    'collectionSite': 20,
}

for attribute, top_k in attributes_and_k.items():
    logging.info(f"Starting similarity search processing for attribute: {attribute} with top_k: {top_k}")
    process_files_for_similarity_search(directory, attribute, top_k)

logging.info("Similarity search processing completed.")
# Out:
# 2024-10-02 12:30:25,822 - INFO - Starting similarity search processing for attribute: collectionSite with top_k: 20
# Processing files:   0%|          | 0/1 [00:00<?, ?it/s]2024-10-02 12:30:25,865 - INFO - Processing file: llm_results_ft_4o_0.8_doi_collectionSite_0_1st.csv for attribute: collectionSite
# 2024-10-02 12:30:25,867 - INFO - Backup created at llm_ft_results/llm_results_ft_4o_0.8_doi_collectionSite_0_1st.csv.bak
# 2024-10-02 12:30:26,354 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-02 12:30:26,394 - INFO - Updated 'restored' from ['10.1002/cbdv.200590016', ['Fortaleza/CE']] to ['10.1002/cbdv.200590016', ['Recife/PE', 'Sao Paulo/SP', 'Rio De Janeiro/RJ', 'Sao Carlos/SP', 'Sao Sebastiao Do Passe/BA', 'Rio Claro/SP', 'Corumba/MS', 'Belem/PA', 'Manaus/AM', 'Araraquara/SP', 'Cunha/SP', 'Cuiaba/MT', 'Teodoro Sampaio/SP', 'Goiania/GO', 'Chapada Dos Guimaraes/MT', 'Campinas/SP', 'Piracicaba/SP', 'Ribeirao Preto/SP', 'Santarem/PA', 'Cordeiropolis/SP']] for DOI ['10.1002/cbdv.200590016', 'Sao Carlos/SP']
# 2024-10-02 12:30:26,966 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-02 12:30:27,003 - INFO - Updated 'restored' from ['10.1002/jobm.200800093', ['Ribeirao Preto/SP']] to ['10.1002/jobm.200800093', ['Ribeirao Preto/SP', 'Piracicaba/SP', 'Sao Paulo/SP', 'Araraquara/SP', 'Ribeirao Preto/SP, Nigrospora sphaerica', 'Rio Claro/SP', 'Iguape/SP', 'Sao Carlos/SP', 'Campinas/SP', 'Rio De Janeiro/RJ', 'Teodoro Sampaio/SP', 'Cordeiropolis/SP', 'Recife/PE', 'Sao Sebastiao Do Passe/BA', 'Cunha/SP', 'Sao Miguel Arcanjo/SP', 'Pirenopolis/GO', 'Corumba/MS', 'Chapada Dos Guimaraes/MT', 'Mogi Guacu/SP']] for DOI ['10.1002/jobm.200800093', 'Ribeirao Preto/SP']
# 2024-10-02 12:30:27,376 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-02 12:30:27,378 - INFO - Updated 'restored' from ['10.1002/ps.1278', ['Pocos De Caldas/MG']] to ['10.1002/ps.1278', ['Pocos De Caldas/MG', 'Pocos De Caldas/MG, Lonchocarpus atropurpureus', 'Vicosa/MG', 'Lavras/MG', 'Chapada Dos Guimaraes/MT', 'Cuiaba/MT', 'Recife/PE', 'Ribeirao Preto/SP', 'Sao Carlos/SP', 'Mogi Guacu/SP', 'Rio Claro/SP', 'Sao Sebastiao Do Passe/BA', 'Campinas/SP', 'Iguape/SP', 'Sao Paulo/SP', 'Sao Miguel Arcanjo/SP', 'Piracicaba/SP', 'Araraquara/SP', 'Cunha/SP', 'Teodoro Sampaio/SP']] for DOI ['10.1002/ps.1278', 'Pocos De Caldas/MG']
# 2024-10-02 12:30:27,683 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10
- INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-02 12:31:06,489 - INFO - Updated 'restored' from ['10.5935/0103-5053.19930018', ['Sao Paulo/SP']] to ['10.5935/0103-5053.19930018', ['Sao Paulo/SP', 'Sao Carlos/SP', 'Piracicaba/SP', 'Campinas/SP', 'Ribeirao Preto/SP', 'Teodoro Sampaio/SP', 'Araraquara/SP', 'Iguape/SP', 'Cunha/SP', 'Rio Claro/SP', 'Sao Miguel Arcanjo/SP', 'Cordeiropolis/SP', 'Rio De Janeiro/RJ', 'Sao Sebastiao Do Passe/BA', 'Recife/PE', 'Peruibe/SP', 'Mogi Guacu/SP', 'Goiania/GO', 'Itirapina/SP', 'Corumba/MS']] for DOI ['10.5935/0103-5053.19930018', 'N/A/ES']
# 2024-10-02 12:31:06,493 - INFO - Updated file saved at llm_ft_results/llm_results_ft_4o_0.8_doi_collectionSite_0_1st.csv
# Processing files: 100%|██████████| 1/1 [00:40<00:00, 40.63s/it]
# 2024-10-02 12:31:06,498 - INFO - Similarity search processing completed.

# %%
#for finetuned model. name 0 1st
import os
import ast
import csv
import re
import logging
import shutil
from tqdm import tqdm
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set your OpenAI API key
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the 'OPENAI_API_KEY' environment variable.")

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

def load_faiss_index(attribute):
    """
    Load the FAISS index for a given attribute.

    Parameters:
    - attribute (str): The attribute name (e.g., 'name').

    Returns:
    - FAISS: The loaded FAISS index object.
    """
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index file for attribute '{attribute}' not found at {index_path}.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(faiss_index, query, top_k):
    """
    Perform a similarity search using the FAISS index.

    Parameters:
    - faiss_index (FAISS): The FAISS index object.
    - query (str): The query string.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - list of tuples: Each tuple contains (Document, score).
    """
    docs_with_score = faiss_index.similarity_search_with_score(query, k=top_k)
    return docs_with_score

def clean_restored_field(restored_str):
    """
    Clean and ensure the 'restored' field is in proper list format.

    Parameters:
    - restored_str (str): The string representation of the 'restored' field.

    Returns:
    - str: Cleaned string in list format.
    """
    restored_str = restored_str.strip()
    if not (restored_str.startswith('[') and restored_str.endswith(']')):
        restored_str = f"[{restored_str}]"
    return restored_str

def process_row(row, faiss_index, attribute, top_k):
    """
    Process a single row by performing similarity search and updating the 'restored' field.

    Parameters:
    - row (dict): The CSV row as a dictionary.
    - faiss_index (FAISS): The FAISS index object.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - dict: The updated row.
    """
    try:
        restored_str = clean_restored_field(row['restored'])
        restored = ast.literal_eval(restored_str)
        # Check if 'restored' has the expected structure
        if isinstance(restored, list) and len(restored) == 2 and isinstance(restored[1], list):
            # Convert all predicted values to strings
            restored[1] = [str(item) for item in restored[1]]
            # Create a query by joining the predicted values
            query = ' '.join(restored[1])
            # Perform similarity search
            docs_with_score = similarity_search(faiss_index, query, top_k)
            if docs_with_score:
                # Extract the most similar entries
                similar_entries = [doc.page_content for doc, _ in docs_with_score]
                # Update the 'restored' field with similar entries
                new_restored_value = [restored[0], similar_entries]
                old_value = row['restored']
                row['restored'] = str(new_restored_value)
                logging.info(f"Updated 'restored' from {old_value} to {new_restored_value} for DOI {row['true']}")
        else:
            logging.warning(f"Unexpected 'restored' format in row: {row}")
    except (ValueError, SyntaxError, TypeError) as e:
        logging.error(f"Error parsing 'restored' field in row {row}: {e}")
    return row

def update_restored_with_similarity_search(file_path, attribute, top_k):
    """
    Update the 'restored' field in the CSV file using similarity search.

    Parameters:
    - file_path (str): Path to the input CSV file.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    backup_file_path = file_path + '.bak'
    shutil.copy(file_path, backup_file_path)
    logging.info(f"Backup created at {backup_file_path}")

    try:
        faiss_index = load_faiss_index(attribute)
    except FileNotFoundError as e:
        logging.error(e)
        return

    temp_file = file_path + '.temp'
    batch_size = 100  # Adjust this based on your available memory

    with open(file_path, 'r', newline='', encoding='utf-8') as infile, \
         open(temp_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()

        batch = []
        for row in tqdm(reader, desc=f"Processing rows in {os.path.basename(file_path)}"):
            batch.append(row)
            if len(batch) >= batch_size:
                processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
                writer.writerows(processed_batch)
                batch = []

        if batch:
            processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
            writer.writerows(processed_batch)

    os.replace(temp_file, file_path)
    logging.info(f"Updated file saved at {file_path}")

def process_files_for_similarity_search(directory, attribute, top_k):
    """
    Process all relevant CSV files in the specified directory for similarity search.

    Parameters:
    - directory (str): Directory containing the CSV files.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    # Updated pattern to match the new filename format for 'name'
    pattern = re.compile(rf'llm_results_ft_4o_0\.8_doi_{re.escape(attribute)}_0_1st\.csv$')
    files = [f for f in os.listdir(directory) if pattern.match(f)]

    if not files:
        logging.warning(f"No files found matching pattern for attribute '{attribute}' in directory '{directory}'.")
        return

    for filename in tqdm(files, desc="Processing files"):
        file_path = os.path.join(directory, filename)
        logging.info(f"Processing file: {filename} for attribute: {attribute}")
        update_restored_with_similarity_search(file_path, attribute, top_k)

# Process only the 'name' attribute with top_k=50
directory = 'llm_ft_results'
attributes_and_k = {
    'name': 50,
}

for attribute, top_k in attributes_and_k.items():
    logging.info(f"Starting similarity search processing for attribute: {attribute} with top_k: {top_k}")
    process_files_for_similarity_search(directory, attribute, top_k)

logging.info("Similarity search processing completed.")
# Out:
# 2024-10-02 14:12:15,929 - INFO - Updated file saved at llm_ft_results/llm_results_ft_4o_0.8_doi_name_0_1st.csv
# Processing files: 100%|██████████| 1/1 [01:45<00:00, 105.39s/it]
# 2024-10-02 14:12:15,980 - INFO - Similarity search processing completed.

# %%
# for finetuned model. bioActivity 0 1st
import os
import ast
import csv
import re
import logging
import shutil
from tqdm import tqdm
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set your OpenAI API key
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the 'OPENAI_API_KEY' environment variable.")

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

def load_faiss_index(attribute):
    """
    Load the FAISS index for a given attribute.

    Parameters:
    - attribute (str): The attribute name (e.g., 'bioActivity').

    Returns:
    - FAISS: The loaded FAISS index object.
    """
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index file for attribute '{attribute}' not found at {index_path}.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(faiss_index, query, top_k):
    """
    Perform a similarity search using the FAISS index.

    Parameters:
    - faiss_index (FAISS): The FAISS index object.
    - query (str): The query string.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - list of tuples: Each tuple contains (Document, score).
    """
    docs_with_score = faiss_index.similarity_search_with_score(query, k=top_k)
    return docs_with_score

def clean_restored_field(restored_str):
    """
    Clean and ensure the 'restored' field is in proper list format.

    Parameters:
    - restored_str (str): The string representation of the 'restored' field.

    Returns:
    - str: Cleaned string in list format.
    """
    restored_str = restored_str.strip()
    if not (restored_str.startswith('[') and restored_str.endswith(']')):
        restored_str = f"[{restored_str}]"
    return restored_str

def process_row(row, faiss_index, attribute, top_k):
    """
    Process a single row by performing similarity search and updating the 'restored' field.

    Parameters:
    - row (dict): The CSV row as a dictionary.
    - faiss_index (FAISS): The FAISS index object.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - dict: The updated row.
    """
    try:
        restored_str = clean_restored_field(row['restored'])
        restored = ast.literal_eval(restored_str)
        # Check if 'restored' has the expected structure
        if isinstance(restored, list) and len(restored) == 2 and isinstance(restored[1], list):
            # Convert all predicted values to strings
            restored[1] = [str(item) for item in restored[1]]
            # Create a query by joining the predicted values
            query = ' '.join(restored[1])
            # Perform similarity search
            docs_with_score = similarity_search(faiss_index, query, top_k)
            if docs_with_score:
                # Extract the most similar entries
                similar_entries = [doc.page_content for doc, _ in docs_with_score]
                # Update the 'restored' field with similar entries
                new_restored_value = [restored[0], similar_entries]
                old_value = row['restored']
                row['restored'] = str(new_restored_value)
                logging.info(f"Updated 'restored' from {old_value} to {new_restored_value} for DOI {row['true']}")
        else:
            logging.warning(f"Unexpected 'restored' format in row: {row}")
    except (ValueError, SyntaxError, TypeError) as e:
        logging.error(f"Error parsing 'restored' field in row {row}: {e}")
    return row

def update_restored_with_similarity_search(file_path, attribute, top_k):
    """
    Update the 'restored' field in the CSV file using similarity search.

    Parameters:
    - file_path (str): Path to the input CSV file.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    backup_file_path = file_path + '.bak'
    shutil.copy(file_path, backup_file_path)
    logging.info(f"Backup created at {backup_file_path}")

    try:
        faiss_index = load_faiss_index(attribute)
    except FileNotFoundError as e:
        logging.error(e)
        return

    temp_file = file_path + '.temp'
    batch_size = 100  # Adjust this based on your available memory

    with open(file_path, 'r', newline='', encoding='utf-8') as infile, \
         open(temp_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()

        batch = []
        for row in tqdm(reader, desc=f"Processing rows in {os.path.basename(file_path)}"):
            batch.append(row)
            if len(batch) >= batch_size:
                processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
                writer.writerows(processed_batch)
                batch = []

        if batch:
            processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
            writer.writerows(processed_batch)

    os.replace(temp_file, file_path)
    logging.info(f"Updated file saved at {file_path}")

def process_files_for_similarity_search(directory, attribute, top_k):
    """
    Process all relevant CSV files in the specified directory for similarity search.

    Parameters:
    - directory (str): Directory containing the CSV files.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    # Updated pattern to match the new filename format
    pattern = re.compile(rf'llm_results_ft_4o_0\.8_doi_{re.escape(attribute)}_0_1st\.csv')
    files = [f for f in os.listdir(directory) if pattern.match(f)]

    if not files:
        logging.warning(f"No files found matching pattern for attribute '{attribute}' in directory '{directory}'.")
        return

    for filename in tqdm(files, desc="Processing files"):
        file_path = os.path.join(directory, filename)
        logging.info(f"Processing file: {filename} for attribute: {attribute}")
        update_restored_with_similarity_search(file_path, attribute, top_k)

# Process only the 'bioActivity' attribute with top_k=5
directory = 'llm_ft_results'
attributes_and_k = {
    'bioActivity': 5,
}

for attribute, top_k in attributes_and_k.items():
    logging.info(f"Starting similarity search processing for attribute: {attribute} with top_k: {top_k}")
    process_files_for_similarity_search(directory, attribute, top_k)

logging.info("Similarity search processing completed.")
# Out:
# 2024-10-03 13:36:53,735 - INFO - Starting similarity search processing for attribute: bioActivity with top_k: 5
# Processing files:   0%|          | 0/1 [00:00<?, ?it/s]2024-10-03 13:36:53,739 - INFO - Processing file: llm_results_ft_4o_0.8_doi_bioActivity_0_1st.csv for attribute: bioActivity
# 2024-10-03 13:36:53,743 - INFO - Backup created at llm_ft_results/llm_results_ft_4o_0.8_doi_bioActivity_0_1st.csv.bak
# 2024-10-03 13:36:54,169 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:54,234 - INFO - Updated 'restored' from ['10.1002/cbdv.200800342', ['Cytotoxic']] to ['10.1002/cbdv.200800342', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1002/cbdv.200800342', 'Cytotoxic']
# 2024-10-03 13:36:54,509 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:54,513 - INFO - Updated 'restored' from ['10.1002/hlca.200890147', ['Antifungal']] to ['10.1002/hlca.200890147', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1002/hlca.200890147', 'Antifungal']
# 2024-10-03 13:36:54,773 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:54,796 - INFO - Updated 'restored' from ['10.1002/jobm.200800093', ['Cytotoxic']] to ['10.1002/jobm.200800093', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1002/jobm.200800093', 'Cytotoxic']
# 2024-10-03 13:36:55,116 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:55,120 - INFO - Updated 'restored' from ['10.1002/ps.1278', ['Insecticidal']] to ['10.1002/ps.1278', ['Insecticidal', 'Molluscicidal', 'Antibacterial', 'Antifungal', 'Antimalarial']] for DOI ['10.1002/ps.1278', 'Insecticidal']
# 2024-10-03 13:36:55,423 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:55,428 - INFO - Updated 'restored' from ['10.1002/ps.478', ['Insecticidal']] to ['10.1002/ps.478', ['Insecticidal', 'Molluscicidal', 'Antibacterial', 'Antifungal', 'Antimalarial']] for DOI ['10.1002/ps.478', 'Insecticidal']
# 2024-10-03 13:36:55,703 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:55,739 - INFO - Updated 'restored' from ['10.1007/s10295-012-1165-2', ['Cytotoxic']] to ['10.1007/s10295-012-1165-2', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1007/s10295-012-1165-2', 'Cytotoxic']
# 2024-10-03 13:36:56,038 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:56,041 - INFO - Updated 'restored' from ['10.1016/0031-9422(73)85048-4', ['Antifungal']] to ['10.1016/0031-9422(73)85048-4', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/0031-9422(73)85048-4', 'Antitrypanosomal']
# 2024-10-03 13:36:56,269 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:56,275 - INFO - Updated 'restored' from ['10.1016/0031-9422(81)80027-1', ['Anesthetic']] to ['10.1016/0031-9422(81)80027-1', ['Anesthetic', 'Antinociceptive', 'Anxiolytic', 'Antichagasic', 'Antibacterial']] for DOI ['10.1016/0031-9422(81)80027-1', 'Anesthetic']
# 2024-10-03 13:36:56,551 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:56,560 - INFO - Updated 'restored' from ['10.1016/0031-9422(90)80024-B', ['Molluscicidal']] to ['10.1016/0031-9422(90)80024-B', ['Molluscicidal', 'Insecticidal', 'Antimalarial', 'Antileishmanial', 'Antibacterial']] for DOI ['10.1016/0031-9422(90)80024-B', 'Molluscicidal']
# 2024-10-03 13:36:56,960 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:56,965 - INFO - Updated 'restored' from ['10.1016/0031-9422(91)85077-D', ['Antifungal']] to ['10.1016/0031-9422(91)85077-D', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/0031-9422(91)85077-D', 'Antifungal']
# 2024-10-03 13:36:57,269 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:57,282 - INFO - Updated 'restored' from ['10.1016/0040-4020(95)00254-6', ['Cytotoxic']] to ['10.1016/0040-4020(95)00254-6', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/0040-4020(95)00254-6', 'Cytotoxic']
# 2024-10-03 13:36:57,575 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:57,585 - INFO - Updated 'restored' from ['10.1016/j.biortech.2010.01.041', ['Inhibition of Subtilisin']] to ['10.1016/j.biortech.2010.01.041', ['Inhibition of Protease', 'Inhibition of Glycosidase', 'Inhibition of Cathepsin B', 'Inhibition of Cathepsin L', 'Inhibition of Cathepsin V']] for DOI ['10.1016/j.biortech.2010.01.041', 'Antiviral']
# 2024-10-03 13:36:57,837 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:57,877 - INFO - Updated 'restored' from ['10.1016/j.biortech.2010.01.041', ['Inhibition of Subtilisin']] to ['10.1016/j.biortech.2010.01.041', ['Inhibition of Protease', 'Inhibition of Glycosidase', 'Inhibition of Cathepsin B', 'Inhibition of Cathepsin L', 'Inhibition of Cathepsin V']] for DOI ['10.1016/j.biortech.2010.01.041', 'Inhibition of Protease']
# 2024-10-03 13:36:58,118 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:58,410 - INFO - Updated 'restored' from ['10.1016/j.bmc.2010.12.056', ['Inhibition of Cathepsin V']] to ['10.1016/j.bmc.2010.12.056', ['Inhibition of Cathepsin V', 'Inhibition of Cathepsin L', 'Inhibition of Cathepsin B', 'Inhibition of Protease', 'Inhibition of Glycosidase']] for DOI ['10.1016/j.bmc.2010.12.056', 'Inhibition of Cathepsin V']
# 2024-10-03 13:36:58,700 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:58,706 - INFO - Updated 'restored' from ['10.1016/j.cbi.2010.08.008', ['Cytotoxic']] to ['10.1016/j.cbi.2010.08.008', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/j.cbi.2010.08.008', 'Anticancer']
# 2024-10-03 13:36:58,959 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:58,962 - INFO - Updated 'restored' from ['10.1016/j.cbi.2010.08.008', ['Cytotoxic']] to ['10.1016/j.cbi.2010.08.008', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/j.cbi.2010.08.008', 'Cytotoxic']
# 2024-10-03 13:36:59,320 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:59,332 - INFO - Updated 'restored' from ['10.1016/j.chroma.2009.02.009', ['Antimalarial']] to ['10.1016/j.chroma.2009.02.009', ['Antimalarial', 'Antitrypanosomal', 'Antileishmanial', 'Antiviral', 'Antifungal']] for DOI ['10.1016/j.chroma.2009.02.009', 'Antitrypanosomal']
# 2024-10-03 13:36:59,543 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:59,549 - INFO - Updated 'restored' from ['10.1016/j.chroma.2009.02.066', ['Antifungal']] to ['10.1016/j.chroma.2009.02.066', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/j.chroma.2009.02.066', 'Antifungal']
# 2024-10-03 13:36:59,836 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:36:59,842 - INFO - Updated 'restored' from ['10.1016/j.jep.2007.09.020', ['Antioxidant']] to ['10.1016/j.jep.2007.09.020', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1016/j.jep.2007.09.020', 'Antileishmanial']
# 2024-10-03 13:37:00,237 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:00,343 - INFO - Updated 'restored' from ['10.1016/j.jfca.2003.09.013', ['Antioxidant']] to ['10.1016/j.jfca.2003.09.013', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1016/j.jfca.2003.09.013', 'Inhibition of Glycosidase']
# 2024-10-03 13:37:00,589 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:00,593 - INFO - Updated 'restored' from ['10.1016/j.jpba.2012.08.028', ['Cytotoxic']] to ['10.1016/j.jpba.2012.08.028', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/j.jpba.2012.08.028', 'Antitrypanosomal']
# 2024-10-03 13:37:01,056 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:01,116 - INFO - Updated 'restored' from ['10.1016/j.jphotobiol.2013.01.006', ['Inhibition of Photosynthesis']] to ['10.1016/j.jphotobiol.2013.01.006', ['Inhibition of ATP synthesis', 'Inhibition of phosphorylating electron transport', 'Inhibition of basal electron transport', 'Inhibition of uncoupled electron transport', 'Inhibition of Glycosidase']] for DOI ['10.1016/j.jphotobiol.2013.01.006', 'Inhibition of uncoupled electron transport']
# 2024-10-03 13:37:01,474 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:01,477 - INFO - Updated 'restored' from ['10.1016/j.jphotobiol.2013.01.006', ['Inhibition of Photosynthesis']] to ['10.1016/j.jphotobiol.2013.01.006', ['Inhibition of ATP synthesis', 'Inhibition of phosphorylating electron transport', 'Inhibition of basal electron transport', 'Inhibition of uncoupled electron transport', 'Inhibition of Glycosidase']] for DOI ['10.1016/j.jphotobiol.2013.01.006', 'Inhibition of basal electron transport']
# 2024-10-03 13:37:01,774 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:01,779 - INFO - Updated 'restored' from ['10.1016/j.micres.2004.06.003', ['Antibacterial']] to ['10.1016/j.micres.2004.06.003', ['Antibacterial', 'Antiviral', 'Antifungal', 'Antimalarial', 'Anti-inflamatory']] for DOI ['10.1016/j.micres.2004.06.003', 'Antibacterial']
# 2024-10-03 13:37:02,023 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:02,034 - INFO - Updated 'restored' from ['10.1016/j.phytochem.2005.04.043', ['Antifungal']] to ['10.1016/j.phytochem.2005.04.043', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/j.phytochem.2005.04.043', 'Antifungal']
# 2024-10-03 13:37:02,389 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:02,417 - INFO - Updated 'restored' from ['10.1016/j.phytochem.2005.06.019', ['Antioxidant']] to ['10.1016/j.phytochem.2005.06.019', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1016/j.phytochem.2005.06.019', 'Antioxidant']
# 2024-10-03 13:37:02,676 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37
- INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:05,778 - INFO - Updated 'restored' from ['10.1016/S0031-9422(00)00225-9', ['Antibacterial']] to ['10.1016/S0031-9422(00)00225-9', ['Antibacterial', 'Antiviral', 'Antifungal', 'Antimalarial', 'Anti-inflamatory']] for DOI ['10.1016/S0031-9422(00)00225-9', 'Antifungal']
# 2024-10-03 13:37:06,073 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:06,076 - INFO - Updated 'restored' from ['10.1016/S0031-9422(00)00225-9', ['Antibacterial']] to ['10.1016/S0031-9422(00)00225-9', ['Antibacterial', 'Antiviral', 'Antifungal', 'Antimalarial', 'Anti-inflamatory']] for DOI ['10.1016/S0031-9422(00)00225-9', 'Antibacterial']
# 2024-10-03 13:37:06,381 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:06,384 - INFO - Updated 'restored' from ['10.1016/S0031-9422(00)00248-X', ['Inhibition of Glycosomal GAPDH']] to ['10.1016/S0031-9422(00)00248-X', ['Inhibition of Glycosidase', 'Inhibition of Myeloperoxodase', 'Inhibition of phosphorylating electron transport', 'Inhibition of ATP synthesis', 'Inhibition of Protease']] for DOI ['10.1016/S0031-9422(00)00248-X', 'Antitrypanosomal']
# 2024-10-03 13:37:06,642 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:06,683 - INFO - Updated 'restored' from ['10.1016/S0031-9422(00)00477-5', ['Antioxidant']] to ['10.1016/S0031-9422(00)00477-5', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1016/S0031-9422(00)00477-5', 'Antioxidant']
# 2024-10-03 13:37:06,995 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:07,000 - INFO - Updated 'restored' from ['10.1016/S0031-9422(01)00079-6', ['Antifungal']] to ['10.1016/S0031-9422(01)00079-6', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/S0031-9422(01)00079-6', 'Cytotoxic']
# 2024-10-03 13:37:07,404 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:07,406 - INFO - Updated 'restored' from ['10.1016/S0031-9422(01)00079-6', ['Antifungal']] to ['10.1016/S0031-9422(01)00079-6', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/S0031-9422(01)00079-6', 'Antifungal']
# 2024-10-03 13:37:07,623 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:07,626 - INFO - Updated 'restored' from ['10.1016/S0031-9422(01)00431-9', ['Antifungal']] to ['10.1016/S0031-9422(01)00431-9', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/S0031-9422(01)00431-9', 'Antifungal']
# 2024-10-03 13:37:07,828 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:07,831 - INFO - Updated 'restored' from ['10.1016/S0031-9422(03)00153-5', ['Antitrypanosomal']] to ['10.1016/S0031-9422(03)00153-5', ['Antitrypanosomal', 'Antimalarial', 'Antileishmanial', 'Antichagasic', 'Antifungal']] for DOI ['10.1016/S0031-9422(03)00153-5', 'Antitrypanosomal']
# 2024-10-03 13:37:08,063 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:08,067 - INFO - Updated 'restored' from ['10.1016/S0031-9422(97)00238-0', ['Antifungal']] to ['10.1016/S0031-9422(97)00238-0', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/S0031-9422(97)00238-0', 'Antifungal']
# 2024-10-03 13:37:08,434 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:08,442 - INFO - Updated 'restored' from ['10.1016/S0031-9422(97)00238-0', ['Antifungal']] to ['10.1016/S0031-9422(97)00238-0', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/S0031-9422(97)00238-0', 'Antioxidant']
# 2024-10-03 13:37:08,838 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:08,859 - INFO - Updated 'restored' from ['10.1016/S0031-9422(97)00598-0', ['Antioxidant']] to ['10.1016/S0031-9422(97)00598-0', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1016/S0031-9422(97)00598-0', 'Antitrypanosomal']
# 2024-10-03 13:37:09,091 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:09,260 - INFO - Updated 'restored' from ['10.1016/S0031-9422(98)00069-7', ['Antifungal']] to ['10.1016/S0031-9422(98)00069-7', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1016/S0031-9422(98)00069-7', 'Inhibition of Glycosidase']
# 2024-10-03 13:37:09,543 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:09,554 - INFO - Updated 'restored' from ['10.1016/S0031-9422(98)00249-0', ['Cytotoxic']] to ['10.1016/S0031-9422(98)00249-0', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/S0031-9422(98)00249-0', 'Cytotoxic']
# 2024-10-03 13:37:09,895 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:09,900 - INFO - Updated 'restored' from ['10.1016/S0031-9422(99)00132-6', ['Cytotoxic']] to ['10.1016/S0031-9422(99)00132-6', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/S0031-9422(99)00132-6', 'Cytotoxic']
# 2024-10-03 13:37:10,181 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:10,408 - INFO - Updated 'restored' from ['10.1016/S0031-9422(99)00132-6', ['Cytotoxic']] to ['10.1016/S0031-9422(99)00132-6', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/S0031-9422(99)00132-6', 'Antifungal']
# 2024-10-03 13:37:10,696 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:10,725 - INFO - Updated 'restored' from ['10.1016/S0031-9422(99)00132-6', ['Cytotoxic']] to ['10.1016/S0031-9422(99)00132-6', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1016/S0031-9422(99)00132-6', 'Anticancer']
# 2024-10-03 13:37:11,096 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:11,229 - INFO - Updated 'restored' from ['10.1021/cc100076k', ['Inhibition of Cathepsin V']] to ['10.1021/cc100076k', ['Inhibition of Cathepsin V', 'Inhibition of Cathepsin L', 'Inhibition of Cathepsin B', 'Inhibition of Protease', 'Inhibition of Glycosidase']] for DOI ['10.1021/cc100076k', 'Inhibition of Cathepsin V']
# 2024-10-03 13:37:11,487 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:11,541 - INFO - Updated 'restored' from ['10.1021/jf00030a035', ['Cytotoxic']] to ['10.1021/jf00030a035', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/jf00030a035', 'Anticancer']
# 2024-10-03 13:37:11,808 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:11,822 - INFO - Updated 'restored' from ['10.1021/jf00030a035', ['Cytotoxic']] to ['10.1021/jf00030a035', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/jf00030a035', 'Cytotoxic']
# 2024-10-03 13:37:12,204 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:12,326 - INFO - Updated 'restored' from ['10.1021/jf063451x', ['Antioxidant']] to ['10.1021/jf063451x', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/jf063451x', 'Antioxidant']
# 2024-10-03 13:37:12,612 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:12,617 - INFO - Updated 'restored' from ['10.1021/jf063451x', ['Antioxidant']] to ['10.1021/jf063451x', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/jf063451x', 'Anti-inflamatory']
# 2024-10-03 13:37:12,953 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:13,115 - INFO - Updated 'restored' from ['10.1021/jf100233y', ['Antioxidant']] to ['10.1021/jf100233y', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/jf100233y', 'Antioxidant']
# 2024-10-03 13:37:13,498 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:13,663 - INFO - Updated 'restored' from ['10.1021/jf60217a066', ['Anesthetic']] to ['10.1021/jf60217a066', ['Anesthetic', 'Antinociceptive', 'Anxiolytic', 'Antichagasic', 'Antibacterial']] for DOI ['10.1021/jf60217a066', 'Insect antennae response']
# 2024-10-03 13:37:14,117 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:14,125 - INFO - Updated 'restored' from ['10.1021/np0103970', ['Antitrypanosomal']] to ['10.1021/np0103970', ['Antitrypanosomal', 'Antimalarial', 'Antileishmanial', 'Antichagasic', 'Antifungal']] for DOI ['10.1021/np0103970', 'Antitrypanosomal']
# 2024-10-03 13:37:14,446 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:14,538 - INFO - Updated 'restored' from ['10.1021/np030100t', ['Antioxidant']] to ['10.1021/np030100t', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/np030100t', 'Antioxidant']
# 2024-10-03 13:37:14,901 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:15,037 - INFO - Updated 'restored' from ['10.1021/np0303963', ['DNA-Damaging']] to ['10.1021/np0303963', ['Genotoxic', 'Mutagenic', 'Cytotoxic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np0303963', 'Cytotoxic']
# 2024-10-03 13:37:15,257 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:15,275 - INFO - Updated 'restored' from ['10.1021/np030530j', ['Antifungal']] to ['10.1021/np030530j', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1021/np030530j', 'Antifungal']
# 2024-10-03 13:37:15,499 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:15,503 - INFO - Updated 'restored' from ['10.1021/np049863m', ['Antioxidant']] to ['10.1021/np049863m', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/np049863m', 'Antioxidant']
# 2024-10-03 13:37:15,838 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:15,950 - INFO - Updated 'restored' from ['10.1021/np060254j', ['Anxiolytic']] to ['10.1021/np060254j', ['Anxiolytic', 'Anesthetic', 'Antinociceptive', 'Antichagasic', 'Antiallergenic']] for DOI ['10.1021/np060254j', 'Anxiolytic']
# 2024-10-03 13:37:16,315 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:16,454 - INFO - Updated 'restored' from ['10.1021/np070312g', ['Antioxidant']] to ['10.1021/np070312g', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/np070312g', 'Antioxidant']
# 2024-10-03 13:37:16,826 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:16,870 - INFO - Updated 'restored' from ['10.1021/np1007476', ['Antioxidant']] to ['10.1021/np1007476', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/np1007476', 'Antioxidant']
# 2024-10-03 13:37:17,080 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:17,089 - INFO - Updated 'restored' from ['10.1021/np1007476', ['Antioxidant']] to ['10.1021/np1007476', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.1021/np1007476', 'Inhibition of Acetylcholinesterase']
# 2024-10-03 13:37:17,545 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:17,554 - INFO - Updated 'restored' from ['10.1021/np100840w', ['Cytotoxic']] to ['10.1021/np100840w', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np100840w', 'Cytotoxic']
# 2024-10-03 13:37:17,890 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:18,006 - INFO - Updated 'restored' from ['10.1021/np4006822', ['Cytotoxic']] to ['10.1021/np4006822', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np4006822', 'Cytotoxic']
# 2024-10-03 13:37:18,368 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:18,470 - INFO - Updated 'restored' from ['10.1021/np4006822', ['Cytotoxic']] to ['10.1021/np4006822', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np4006822', 'Antileishmanial']
# 2024-10-03 13:37:18,704 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:18,799 - INFO - Updated 'restored' from ['10.1021/np4006822', ['Cytotoxic']] to ['10.1021/np4006822', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np4006822', 'Inhibition of Acetylcholinesterase']
# 2024-10-03 13:37:19,114 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:19,143 - INFO - Updated 'restored' from ['10.1021/np500453x', ['Antichagasic']] to ['10.1021/np500453x', ['Antichagasic', 'Antileishmanial', 'Antitrypanosomal', 'Anti-inflamatory', 'Antiallergenic']] for DOI ['10.1021/np500453x', 'Inhibition of Cathepsin B']
# 2024-10-03 13:37:19,413 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:19,420 - INFO - Updated 'restored' from ['10.1021/np500453x', ['Antichagasic']] to ['10.1021/np500453x', ['Antichagasic', 'Antileishmanial', 'Antitrypanosomal', 'Anti-inflamatory', 'Antiallergenic']] for DOI ['10.1021/np500453x', 'Antimalarial']
# 2024-10-03 13:37:19,758 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:19,828 - INFO - Updated 'restored' from ['10.1021/np500453x', ['Antichagasic']] to ['10.1021/np500453x', ['Antichagasic', 'Antileishmanial', 'Antitrypanosomal', 'Anti-inflamatory', 'Antiallergenic']] for DOI ['10.1021/np500453x', 'Anticancer']
# 2024-10-03 13:37:20,103 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:20,117 - INFO - Updated 'restored' from ['10.1021/np500453x', ['Antichagasic']] to ['10.1021/np500453x', ['Antichagasic', 'Antileishmanial', 'Antitrypanosomal', 'Anti-inflamatory', 'Antiallergenic']] for DOI ['10.1021/np500453x', 'Inhibition of Cathepsin L']
# 2024-10-03 13:37:20,383 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:20,418 - INFO - Updated 'restored' from ['10.1021/np50086a012', ['Cytotoxic']] to ['10.1021/np50086a012', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np50086a012', 'Molluscicidal']
# 2024-10-03 13:37:20,701 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:20,713 - INFO - Updated 'restored' from ['10.1021/np800106x', ['Antibacterial']] to ['10.1021/np800106x', ['Antibacterial', 'Antiviral', 'Antifungal', 'Antimalarial', 'Anti-inflamatory']] for DOI ['10.1021/np800106x', 'Antibacterial']
# 2024-10-03 13:37:20,915 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:20,922 - INFO - Updated 'restored' from ['10.1021/np800612x', ['Cytotoxic']] to ['10.1021/np800612x', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np800612x', 'Antiangiogenic']
# 2024-10-03 13:37:21,231 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:21,239 - INFO - Updated 'restored' from ['10.1021/np800612x', ['Cytotoxic']] to ['10.1021/np800612x', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np800612x', 'Cytotoxic']
# 2024-10-03 13:37:21,560 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:21,669 - INFO - Updated 'restored' from ['10.1021/np800612x', ['Cytotoxic']] to ['10.1021/np800612x', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np800612x', 'Antifungal']
# 2024-10-03 13:37:21,948 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:21,989 - INFO - Updated 'restored' from ['10.1021/np9004079', ['Cytotoxic']] to ['10.1021/np9004079', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1021/np9004079', 'Cytotoxic']
# 2024-10-03 13:37:22,357 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:22,409 - INFO - Updated 'restored' from ['10.1021/np9703656', ['Antifungal']] to ['10.1021/np9703656', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1021/np9703656', 'Antifungal']
# 2024-10-03 13:37:22,619 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:22,624 - INFO - Updated 'restored' from ['10.1021/np9704617', ['Antifungal']] to ['10.1021/np9704617', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1021/np9704617', 'Antifungal']
# 2024-10-03 13:37:23,072 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37
- INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:29,223 - INFO - Updated 'restored' from ['10.1515/znc-2002-5-602', ['Cytotoxic']] to ['10.1515/znc-2002-5-602', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1515/znc-2002-5-602', 'Anticancer']
# 2024-10-03 13:37:29,546 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:29,627 - INFO - Updated 'restored' from ['10.1515/znc-2002-5-602', ['Cytotoxic']] to ['10.1515/znc-2002-5-602', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1515/znc-2002-5-602', 'Cytotoxic']
# 2024-10-03 13:37:30,039 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:30,082 - INFO - Updated 'restored' from ['10.1515/znc-2008-5-611', ['Inhibition of Glycosomal Glyceraldehyde-3-Phosphate Dehydrogenase']] to ['10.1515/znc-2008-5-611', ['Inhibition of Glycosidase', 'Inhibition of phosphorylating electron transport', 'Inhibition of Myeloperoxodase', 'Inhibition of ATP synthesis', 'Inhibition of basal electron transport']] for DOI ['10.1515/znc-2008-5-611', 'Antitrypanosomal']
# 2024-10-03 13:37:30,284 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:30,298 - INFO - Updated 'restored' from ['10.1515/znc-2009-11-1212', ['Antifungal']] to ['10.1515/znc-2009-11-1212', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1515/znc-2009-11-1212', 'Inhibition of Acetylcholinesterase']
# 2024-10-03 13:37:30,500 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:30,506 - INFO - Updated 'restored' from ['10.1515/znc-2011-5-607', ['Insecticidal']] to ['10.1515/znc-2011-5-607', ['Insecticidal', 'Molluscicidal', 'Antibacterial', 'Antifungal', 'Antimalarial']] for DOI ['10.1515/znc-2011-5-607', 'Insecticidal']
# 2024-10-03 13:37:30,856 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:30,865 - INFO - Updated 'restored' from ['10.1590/S0073-47212009000100009', ['Insecticidal']] to ['10.1590/S0073-47212009000100009', ['Insecticidal', 'Molluscicidal', 'Antibacterial', 'Antifungal', 'Antimalarial']] for DOI ['10.1590/S0073-47212009000100009', 'Insecticidal']
# 2024-10-03 13:37:31,082 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:31,088 - INFO - Updated 'restored' from ['10.1590/S0100-40421998000600005', ['Antifungal']] to ['10.1590/S0100-40421998000600005', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1590/S0100-40421998000600005', 'Antifungal']
# 2024-10-03 13:37:31,434 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:31,566 - INFO - Updated 'restored' from ['10.1590/S0100-40422002000300002', ['Antifungal']] to ['10.1590/S0100-40422002000300002', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1590/S0100-40422002000300002', 'Cytotoxic']
# 2024-10-03 13:37:31,808 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:31,842 - INFO - Updated 'restored' from ['10.1590/S0100-40422004000200005', ['Cytotoxic']] to ['10.1590/S0100-40422004000200005', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.1590/S0100-40422004000200005', 'Cytotoxic']
# 2024-10-03 13:37:32,163 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:32,265 - INFO - Updated 'restored' from ['10.1590/S0100-40422005000400009', ['Antifungal']] to ['10.1590/S0100-40422005000400009', ['Antifungal', 'Antiviral', 'Antibacterial', 'Antimalarial', 'Anticancer']] for DOI ['10.1590/S0100-40422005000400009', 'Antifungal']
# 2024-10-03 13:37:32,698 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37
- INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:45,813 - INFO - Updated 'restored' from ['10.1590/S0103-50532009000400008', ['Antimalarial']] to ['10.1590/S0103-50532009000400008', ['Antimalarial', 'Antitrypanosomal', 'Antileishmanial', 'Antiviral', 'Antifungal']] for DOI ['10.1590/S0103-50532009000400008', 'Antimalarial']
# 2024-10-03 13:37:46,169 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:46,284 - INFO - Updated 'restored' from ['10.1590/S0103-50532009000400008', ['Antimalarial']] to ['10.1590/S0103-50532009000400008', ['Antimalarial', 'Antitrypanosomal', 'Antileishmanial', 'Antiviral', 'Antifungal']] for DOI ['10.1590/S0103-50532009000400008', 'Antitrypanosomal']
# 2024-10-03 13:37:46,486 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:46,495 - INFO - Updated 'restored' from ['10.1590/S0103-50532010000500016', ['Insecticidal']] to ['10.1590/S0103-50532010000500016', ['Insecticidal', 'Molluscicidal', 'Antibacterial', 'Antifungal', 'Antimalarial']] for DOI ['10.1590/S0103-50532010000500016', 'Insecticidal']
# 2024-10-03 13:37:46,830 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:46,905 - INFO - Updated 'restored' from ['10.1590/S1519-566X2008000600013', ['Insecticidal']] to ['10.1590/S1519-566X2008000600013', ['Insecticidal', 'Molluscicidal', 'Antibacterial', 'Antifungal', 'Antimalarial']] for DOI ['10.1590/S1519-566X2008000600013', 'Insecticidal']
# 2024-10-03 13:37:47,163 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:47,180 - INFO - Updated 'restored' from ['10.2174/187152010794728620', ['Cytotoxic']] to ['10.2174/187152010794728620', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.2174/187152010794728620', 'Cell growth inhbition']
# 2024-10-03 13:37:47,425 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:47,432 - INFO - Updated 'restored' from ['10.3390/molecules15129205', ['Inhibition of Acetylcholinesterase']] to ['10.3390/molecules15129205', ['Inhibition of Acetylcholinesterase', 'Inhibition of ATP synthesis', 'Inhibition of phosphorylating electron transport', 'Inhibition of Protease', 'Inhibition of basal electron transport']] for DOI ['10.3390/molecules15129205', 'Inhibition of Acetylcholinesterase']
# 2024-10-03 13:37:47,690 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:47,698 - INFO - Updated 'restored' from ['10.3390/molecules190812031', ['Antileishmanial']] to ['10.3390/molecules190812031', ['Antileishmanial', 'Antimalarial', 'Antitrypanosomal', 'Antichagasic', 'Antifungal']] for DOI ['10.3390/molecules190812031', 'Antileishmanial']
# 2024-10-03 13:37:47,956 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:47,984 - INFO - Updated 'restored' from ['10.3390/molecules190812031', ['Antileishmanial']] to ['10.3390/molecules190812031', ['Antileishmanial', 'Antimalarial', 'Antitrypanosomal', 'Antichagasic', 'Antifungal']] for DOI ['10.3390/molecules190812031', 'Insecticidal']
# 2024-10-03 13:37:48,223 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:48,232 - INFO - Updated 'restored' from ['10.4067/S0717-97072009000300004', ['Cytotoxic']] to ['10.4067/S0717-97072009000300004', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.4067/S0717-97072009000300004', 'Inhibition of Glycosidase']
# 2024-10-03 13:37:48,579 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:48,585 - INFO - Updated 'restored' from ['10.5935/0100-4042.20140049', ['Cytotoxic']] to ['10.5935/0100-4042.20140049', ['Cytotoxic', 'Genotoxic', 'Mutagenic', 'Anticancer', 'Antiviral']] for DOI ['10.5935/0100-4042.20140049', 'Cytotoxic']
# 2024-10-03 13:37:49,010 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:49,043 - INFO - Updated 'restored' from ['10.5935/0103-5053.19930018', ['Antioxidant']] to ['10.5935/0103-5053.19930018', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.5935/0103-5053.19930018', 'Antitrypanosomal']
# 2024-10-03 13:37:49,296 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-03 13:37:49,301 - INFO - Updated 'restored' from ['10.5935/0103-5053.19960024', ['Antioxidant']] to ['10.5935/0103-5053.19960024', ['Antioxidant', 'Anticancer', 'Anti-inflamatory', 'Antiviral', 'Antibacterial']] for DOI ['10.5935/0103-5053.19960024', 'Antifungal']
# 2024-10-03 13:37:49,305 - INFO - Updated file saved at llm_ft_results/llm_results_ft_4o_0.8_doi_bioActivity_0_1st.csv
# Processing files: 100%|██████████| 1/1 [00:55<00:00, 55.57s/it]
# 2024-10-03 13:37:49,313 - INFO - Similarity search processing completed.

# %%
# for finetuned model. collectionSpecie 0 1st
import os
import ast
import csv
import re
import logging
import shutil
from tqdm import tqdm
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set your OpenAI API key
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the 'OPENAI_API_KEY' environment variable.")

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

def load_faiss_index(attribute):
    """
    Load the FAISS index for a given attribute.

    Parameters:
    - attribute (str): The attribute name (e.g., 'collectionSpecie').

    Returns:
    - FAISS: The loaded FAISS index object.
    """
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index file for attribute '{attribute}' not found at {index_path}.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(faiss_index, query, top_k):
    """
    Perform a similarity search using the FAISS index.

    Parameters:
    - faiss_index (FAISS): The FAISS index object.
    - query (str): The query string.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - list of tuples: Each tuple contains (Document, score).
    """
    docs_with_score = faiss_index.similarity_search_with_score(query, k=top_k)
    return docs_with_score

def clean_restored_field(restored_str):
    """
    Clean and ensure the 'restored' field is in proper list format.

    Parameters:
    - restored_str (str): The string representation of the 'restored' field.

    Returns:
    - str: Cleaned string in list format.
    """
    restored_str = restored_str.strip()
    if not (restored_str.startswith('[') and restored_str.endswith(']')):
        restored_str = f"[{restored_str}]"
    return restored_str

def process_row(row, faiss_index, attribute, top_k):
    """
    Process a single row by performing similarity search and updating the 'restored' field.

    Parameters:
    - row (dict): The CSV row as a dictionary.
    - faiss_index (FAISS): The FAISS index object.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - dict: The updated row.
    """
    try:
        restored_str = clean_restored_field(row['restored'])
        restored = ast.literal_eval(restored_str)
        # Check if 'restored' has the expected structure
        if isinstance(restored, list) and len(restored) == 2 and isinstance(restored[1], list):
            # Convert all predicted values to strings
            restored[1] = [str(item) for item in restored[1]]
            # Create a query by joining the predicted values
            query = ' '.join(restored[1])
            # Perform similarity search
            docs_with_score = similarity_search(faiss_index, query, top_k)
            if docs_with_score:
                # Extract the most similar entries
                similar_entries = [doc.page_content for doc, _ in docs_with_score]
                # Update the 'restored' field with similar entries
                new_restored_value = [restored[0], similar_entries]
                old_value = row['restored']
                row['restored'] = str(new_restored_value)
                logging.info(f"Updated 'restored' from {old_value} to {new_restored_value} for DOI {row['true']}")
        else:
            logging.warning(f"Unexpected 'restored' format in row: {row}")
    except (ValueError, SyntaxError, TypeError) as e:
        logging.error(f"Error parsing 'restored' field in row {row}: {e}")
    return row

def update_restored_with_similarity_search(file_path, attribute, top_k):
    """
    Update the 'restored' field in the CSV file using similarity search.

    Parameters:
    - file_path (str): Path to the input CSV file.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    backup_file_path = file_path + '.bak'
    shutil.copy(file_path, backup_file_path)
    logging.info(f"Backup created at {backup_file_path}")

    try:
        faiss_index = load_faiss_index(attribute)
    except FileNotFoundError as e:
        logging.error(e)
        return

    temp_file = file_path + '.temp'
    batch_size = 100  # Adjust this based on your available memory

    with open(file_path, 'r', newline='', encoding='utf-8') as infile, \
         open(temp_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()

        batch = []
        for row in tqdm(reader, desc=f"Processing rows in {os.path.basename(file_path)}"):
            batch.append(row)
            if len(batch) >= batch_size:
                processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
                writer.writerows(processed_batch)
                batch = []

        if batch:
            processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
            writer.writerows(processed_batch)

    os.replace(temp_file, file_path)
    logging.info(f"Updated file saved at {file_path}")

def process_files_for_similarity_search(directory, attribute, top_k):
    """
    Process all relevant CSV files in the specified directory for similarity search.

    Parameters:
    - directory (str): Directory containing the CSV files.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    # Updated pattern to match the new filename format
    pattern = re.compile(rf'llm_results_ft_4o_0\.8_doi_{re.escape(attribute)}_0_1st\.csv')
    files = [f for f in os.listdir(directory) if pattern.match(f)]

    if not files:
        logging.warning(f"No files found matching pattern for attribute '{attribute}' in directory '{directory}'.")
        return

    for filename in tqdm(files, desc="Processing files"):
        file_path = os.path.join(directory, filename)
        logging.info(f"Processing file: {filename} for attribute: {attribute}")
        update_restored_with_similarity_search(file_path, attribute, top_k)

# Process only the 'collectionSpecie' attribute with top_k=50
directory = 'llm_ft_results'
attributes_and_k = {
    'collectionSpecie': 50,
}

for attribute, top_k in attributes_and_k.items():
    logging.info(f"Starting similarity search processing for attribute: {attribute} with top_k: {top_k}")
    process_files_for_similarity_search(directory, attribute, top_k)

logging.info("Similarity search processing completed.")
# Out:
# 2024-10-04 13:03:07,290 - INFO - Starting similarity search processing for attribute: collectionSpecie with top_k: 50
# Processing files:   0%|          | 0/1 [00:00<?, ?it/s]2024-10-04 13:03:07,301 - INFO - Processing file: llm_results_ft_4o_0.8_doi_collectionSpecie_0_1st.csv for attribute: collectionSpecie
# 2024-10-04 13:03:07,303 - INFO - Backup created at llm_ft_results/llm_results_ft_4o_0.8_doi_collectionSpecie_0_1st.csv.bak
# 2024-10-04 13:03:07,305 - INFO - Loading faiss.
# 2024-10-04 13:03:07,359 - INFO - Successfully loaded faiss.
# 2024-10-04 13:03:07,877 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:03:07,898 - INFO - Updated 'restored' from ['10.1002/cbdv.200590016', ['Aegle marmelos (Rutaceae)']] to ['10.1002/cbdv.200590016', ['Galipea bracteata (Rutaceae)', 'Neoraputia alba (Rutaceae)', 'Pilocarpus spicatus (Rutaceae)', 'Angostura paniculata (Rutaceae)', 'Almeidea rubra (Rutaceae)', 'Balfourodendron riedelianum (Rutaceae)', 'Conchocarpus heterophyllus (Rutaceae)', 'Citrus sp. (Rutaceae)', 'Neoraputia magnifica (Rutaceae)', 'Cedrela fruticosa (Meliaceae), Neoraputia magnifica (Rutaceae), Neoraputia alba (Rutaceae)', 'Iryanthera juruensis (Myristicaceae)', 'Rudgea viburnioides (Rubiaceae)', 'Chimarrhis turbinata (Rubiaceae)', 'Hortia superba (Rutaceae)', 'Raulinoa echinata (Rutaceae)', 'Citrus sinensis (Rutaceae)', 'Raulinoa echinata (Rutaceae), Swietenia macrophylla (Meliaceae)', 'Cedrela odorata (Meliaceae)', 'Maytenus aquifolium (Celastraceae)', 'Alibertia edulis (Rubiaceae)', 'Trichilia elegans (Meliaceae)', 'Eucalyptus maculata', 'Pothomorphe umbellata (Piperaceae)', 'Erythrina mulungu (Fabaceae)', 'Salacia campestris (Celastraceae)', 'Ouratea multiflora (Ochnaceae)', 'Spiranthera odoratissima St. odoratissima (Rutaceae)', 'Alibertia macrophylla (Rubiaceae)', 'Coussarea hydrangeifolia (Rubiaceae)', 'Siphoneugena densiflora (Myrtaceae)', 'Rapanea lancifolia (Myrsinaceae)', 'Rapanea umbellata,Myrsine cuneifolia (Myrsinaceae)', 'Michelia champaca (Magnoliaceae)', 'Alchornea glandulosa (Euphorbiaceae)', 'Maytenus ilicifolia (Celastraceae)', 'Alibertia sessilis (Rubiaceae)', 'Amorpha fruticosa', 'Tocoyena brasiliensis (Rubiaceae)', 'Cnidoscolus vitifolius (Euphorbiaceae)', 'Tocoyena formosa (Rubiaceae)', 'Calycophyllum spruceanum (Rubiaceae)', 'Swartzia langsdorfii (Fabaceae)', 'Stemodia foliosa (Scrophulariaceae)', 'Pilocarpus riedelianus', 'Esenbeckia leiocarpa', 'Pilocarpus grandiflorus', 'Croton zehntneri (Euphorbiaceae)', 'Chrysophyllum marginatum (Sapotaceae)', 'Cinnamomum australe (Lauraceae)', 'Senna multijuga (Fabaceae)']] for DOI ['10.1002/cbdv.200590016', 'Salacia campestris (Celastraceae)']
# 2024-10-04 13:03:08,286 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13
# Processing files: 100%|██████████| 1/1 [00:51<00:00, 51.69s/it]
# 2024-10-04 13:03:58,993 - INFO - Similarity search processing completed.

# %%
# for finetuned model. collectionType 0 1st
import os
import ast
import csv
import re
import logging
import shutil
from tqdm import tqdm
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Set your OpenAI API key
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the 'OPENAI_API_KEY' environment variable.")

# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# Directory containing the FAISS indexes
index_directory = 'faiss_index_trained'

def load_faiss_index(attribute):
    """
    Load the FAISS index for a given attribute.

    Parameters:
    - attribute (str): The attribute name (e.g., 'collectionType').

    Returns:
    - FAISS: The loaded FAISS index object.
    """
    index_path = os.path.join(index_directory, f'unique_{attribute}.txt.index')
    if not os.path.exists(index_path):
        raise FileNotFoundError(f"FAISS index file for attribute '{attribute}' not found at {index_path}.")
    return FAISS.load_local(index_path, embeddings, allow_dangerous_deserialization=True)

def similarity_search(faiss_index, query, top_k):
    """
    Perform a similarity search using the FAISS index.

    Parameters:
    - faiss_index (FAISS): The FAISS index object.
    - query (str): The query string.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - list of tuples: Each tuple contains (Document, score).
    """
    docs_with_score = faiss_index.similarity_search_with_score(query, k=top_k)
    return docs_with_score

def clean_restored_field(restored_str):
    """
    Clean and ensure the 'restored' field is in proper list format.

    Parameters:
    - restored_str (str): The string representation of the 'restored' field.

    Returns:
    - str: Cleaned string in list format.
    """
    restored_str = restored_str.strip()
    if not (restored_str.startswith('[') and restored_str.endswith(']')):
        restored_str = f"[{restored_str}]"
    return restored_str

def process_row(row, faiss_index, attribute, top_k):
    """
    Process a single row by performing similarity search and updating the 'restored' field.

    Parameters:
    - row (dict): The CSV row as a dictionary.
    - faiss_index (FAISS): The FAISS index object.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.

    Returns:
    - dict: The updated row.
    """
    try:
        restored_str = clean_restored_field(row['restored'])
        restored = ast.literal_eval(restored_str)
        # Check if 'restored' has the expected structure
        if isinstance(restored, list) and len(restored) == 2 and isinstance(restored[1], list):
            # Convert all predicted values to strings
            restored[1] = [str(item) for item in restored[1]]
            # Create a query by joining the predicted values
            query = ' '.join(restored[1])
            # Perform similarity search
            docs_with_score = similarity_search(faiss_index, query, top_k)
            if docs_with_score:
                # Extract the most similar entries
                similar_entries = [doc.page_content for doc, _ in docs_with_score]
                # Update the 'restored' field with similar entries
                new_restored_value = [restored[0], similar_entries]
                old_value = row['restored']
                row['restored'] = str(new_restored_value)
                logging.info(f"Updated 'restored' from {old_value} to {new_restored_value} for DOI {row['true']}")
        else:
            logging.warning(f"Unexpected 'restored' format in row: {row}")
    except (ValueError, SyntaxError, TypeError) as e:
        logging.error(f"Error parsing 'restored' field in row {row}: {e}")
    return row

def update_restored_with_similarity_search(file_path, attribute, top_k):
    """
    Update the 'restored' field in the CSV file using similarity search.

    Parameters:
    - file_path (str): Path to the input CSV file.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    backup_file_path = file_path + '.bak'
    shutil.copy(file_path, backup_file_path)
    logging.info(f"Backup created at {backup_file_path}")

    try:
        faiss_index = load_faiss_index(attribute)
    except FileNotFoundError as e:
        logging.error(e)
        return

    temp_file = file_path + '.temp'
    batch_size = 100  # Adjust this based on your available memory

    with open(file_path, 'r', newline='', encoding='utf-8') as infile, \
         open(temp_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()

        batch = []
        for row in tqdm(reader, desc=f"Processing rows in {os.path.basename(file_path)}"):
            batch.append(row)
            if len(batch) >= batch_size:
                processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
                writer.writerows(processed_batch)
                batch = []

        if batch:
            processed_batch = [process_row(r, faiss_index, attribute, top_k) for r in batch]
            writer.writerows(processed_batch)

    os.replace(temp_file, file_path)
    logging.info(f"Updated file saved at {file_path}")

def process_files_for_similarity_search(directory, attribute, top_k):
    """
    Process all relevant CSV files in the specified directory for similarity search.

    Parameters:
    - directory (str): Directory containing the CSV files.
    - attribute (str): The attribute being processed.
    - top_k (int): Number of top similar documents to retrieve.
    """
    # Updated pattern to match the new filename format
    pattern = re.compile(rf'llm_results_ft_4o_0\.8_doi_{re.escape(attribute)}_0_1st\.csv')
    files = [f for f in os.listdir(directory) if pattern.match(f)]

    if not files:
        logging.warning(f"No files found matching pattern for attribute '{attribute}' in directory '{directory}'.")
        return

    for filename in tqdm(files, desc="Processing files"):
        file_path = os.path.join(directory, filename)
        logging.info(f"Processing file: {filename} for attribute: {attribute}")
        update_restored_with_similarity_search(file_path, attribute, top_k)

# Process only the 'collectionType' attribute with top_k=1
directory = 'llm_ft_results'
attributes_and_k = {
    'collectionType': 1,
}

for attribute, top_k in attributes_and_k.items():
    logging.info(f"Starting similarity search processing for attribute: {attribute} with top_k: {top_k}")
    process_files_for_similarity_search(directory, attribute, top_k)

logging.info("Similarity search processing completed.")
# Out:
# 2024-10-04 13:29:42,426 - INFO - Starting similarity search processing for attribute: collectionType with top_k: 1
# Processing files:   0%|          | 0/1 [00:00<?, ?it/s]2024-10-04 13:29:42,430 - INFO - Processing file: llm_results_ft_4o_0.8_doi_collectionType_0_1st.csv for attribute: collectionType
# 2024-10-04 13:29:42,433 - INFO - Backup created at llm_ft_results/llm_results_ft_4o_0.8_doi_collectionType_0_1st.csv.bak
# 2024-10-04 13:29:42,866 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:42,875 - INFO - Updated 'restored' from ['10.1002/cbdv.200590016', ['Plant Isolated']] to ['10.1002/cbdv.200590016', ['Plant Isolated']] for DOI ['10.1002/cbdv.200590016', 'Plant Isolated']
# 2024-10-04 13:29:43,171 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:43,207 - INFO - Updated 'restored' from ['10.1002/cbdv.200800342', ['Plant Isolated']] to ['10.1002/cbdv.200800342', ['Plant Isolated']] for DOI ['10.1002/cbdv.200800342', 'Plant Isolated']
# 2024-10-04 13:29:43,378 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:43,383 - INFO - Updated 'restored' from ['10.1002/hlca.200890147', ['Plant Isolated']] to ['10.1002/hlca.200890147', ['Plant Isolated']] for DOI ['10.1002/hlca.200890147', 'Plant Isolated']
# 2024-10-04 13:29:43,786 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:43,790 - INFO - Updated 'restored' from ['10.1002/jobm.200800093', ['Microorganism isolated']] to ['10.1002/jobm.200800093', ['Microorganism isolated']] for DOI ['10.1002/jobm.200800093', 'Microorganism isolated']
# 2024-10-04 13:29:43,990 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:43,994 - INFO - Updated 'restored' from ['10.1002/ps.478', ['Plant Isolated']] to ['10.1002/ps.478', ['Plant Isolated']] for DOI ['10.1002/ps.478', 'Plant Isolated']
# 2024-10-04 13:29:44,297 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:44,301 - INFO - Updated 'restored' from ['10.1002/ptr.1249', ['Plant Isolated']] to ['10.1002/ptr.1249', ['Plant Isolated']] for DOI ['10.1002/ptr.1249', 'Plant Isolated']
# 2024-10-04 13:29:44,707 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:44,711 - INFO - Updated 'restored' from ['10.1007/s10295-012-1165-2', ['Plant Isolated']] to ['10.1007/s10295-012-1165-2', ['Plant Isolated']] for DOI ['10.1007/s10295-012-1165-2', 'Plant Isolated']
# 2024-10-04 13:29:45,219 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:45,224 - INFO - Updated 'restored' from ['10.1016/0031-9422(73)85048-4', ['Plant Isolated']] to ['10.1016/0031-9422(73)85048-4', ['Plant Isolated']] for DOI ['10.1016/0031-9422(73)85048-4', 'Plant Isolated']
# 2024-10-04 13:29:45,629 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:45,632 - INFO - Updated 'restored' from ['10.1016/0031-9422(81)80027-1', ['Plant Isolated']] to ['10.1016/0031-9422(81)80027-1', ['Plant Isolated']] for DOI ['10.1016/0031-9422(81)80027-1', 'Plant Isolated']
# 2024-10-04 13:29:45,880 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:45,918 - INFO - Updated 'restored' from ['10.1016/0031-9422(90)80024-B', ['Plant Isolated']] to ['10.1016/0031-9422(90)80024-B', ['Plant Isolated']] for DOI ['10.1016/0031-9422(90)80024-B', 'Plant Isolated']
# 2024-10-04 13:29:46,653 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:46,702 - INFO - Updated 'restored' from ['10.1016/0031-9422(91)85077-D', ['Plant Isolated']] to ['10.1016/0031-9422(91)85077-D', ['Plant Isolated']] for DOI ['10.1016/0031-9422(91)85077-D', 'Plant Isolated']
# 2024-10-04 13:29:47,165 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:47,194 - INFO - Updated 'restored' from ['10.1016/0040-4020(95)00254-6', ['Plant Isolated']] to ['10.1016/0040-4020(95)00254-6', ['Plant Isolated']] for DOI ['10.1016/0040-4020(95)00254-6', 'Plant Isolated']
# 2024-10-04 13:29:47,388 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:47,393 - INFO - Updated 'restored' from ['10.1016/j.biortech.2010.01.041', ['Plant Isolated']] to ['10.1016/j.biortech.2010.01.041', ['Plant Isolated']] for DOI ['10.1016/j.biortech.2010.01.041', 'Biotransformation Product']
# 2024-10-04 13:29:48,087 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13
- INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:57,109 - INFO - Updated 'restored' from ['10.1016/S0031-9422(98)00249-0', ['Plant Isolated']] to ['10.1016/S0031-9422(98)00249-0', ['Plant Isolated']] for DOI ['10.1016/S0031-9422(98)00249-0', 'Plant Isolated']
# 2024-10-04 13:29:57,611 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:57,617 - INFO - Updated 'restored' from ['10.1016/S0031-9422(99)00132-6', ['Plant Isolated']] to ['10.1016/S0031-9422(99)00132-6', ['Plant Isolated']] for DOI ['10.1016/S0031-9422(99)00132-6', 'Plant Isolated']
# 2024-10-04 13:29:58,025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:58,032 - INFO - Updated 'restored' from ['10.1021/cc100076k', ['Plant Isolated']] to ['10.1021/cc100076k', ['Plant Isolated']] for DOI ['10.1021/cc100076k', 'Plant Isolated']
# 2024-10-04 13:29:58,441 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:58,496 - INFO - Updated 'restored' from ['10.1021/jf00030a035', ['Plant Isolated']] to ['10.1021/jf00030a035', ['Plant Isolated']] for DOI ['10.1021/jf00030a035', 'Plant Isolated']
# 2024-10-04 13:29:58,841 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:58,849 - INFO - Updated 'restored' from ['10.1021/jf063451x', ['Plant Isolated']] to ['10.1021/jf063451x', ['Plant Isolated']] for DOI ['10.1021/jf063451x', 'Plant Isolated']
# 2024-10-04 13:29:59,148 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:59,183 - INFO - Updated 'restored' from ['10.1021/jf100233y', ['Plant Isolated']] to ['10.1021/jf100233y', ['Plant Isolated']] for DOI ['10.1021/jf100233y', 'Plant Isolated']
# 2024-10-04 13:29:59,453 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:59,482 - INFO - Updated 'restored' from ['10.1021/jf100233y', ['Plant Isolated']] to ['10.1021/jf100233y', ['Plant Isolated']] for DOI ['10.1021/jf100233y', 'Semisynthesis Product']
# 2024-10-04 13:29:59,867 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:29:59,874 - INFO - Updated 'restored' from ['10.1021/jf60217a066', ['Plant Isolated']] to ['10.1021/jf60217a066', ['Plant Isolated']] for DOI ['10.1021/jf60217a066', 'Plant Isolated']
# 2024-10-04 13:30:00,170 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:00,186 - INFO - Updated 'restored' from ['10.1021/np0103970', ['Plant Isolated']] to ['10.1021/np0103970', ['Plant Isolated']] for DOI ['10.1021/np0103970', 'Plant Isolated']
# 2024-10-04 13:30:00,989 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:01,090 - INFO - Updated 'restored' from ['10.1021/np030100t', ['Plant Isolated']] to ['10.1021/np030100t', ['Plant Isolated']] for DOI ['10.1021/np030100t', 'Plant Isolated']
# 2024-10-04 13:30:01,338 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:01,345 - INFO - Updated 'restored' from ['10.1021/np0303963', ['Plant Isolated']] to ['10.1021/np0303963', ['Plant Isolated']] for DOI ['10.1021/np0303963', 'Plant Isolated']
# 2024-10-04 13:30:01,809 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:01,816 - INFO - Updated 'restored' from ['10.1021/np030530j', ['Plant Isolated']] to ['10.1021/np030530j', ['Plant Isolated']] for DOI ['10.1021/np030530j', 'Plant Isolated']
# 2024-10-04 13:30:02,322 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:02,328 - INFO - Updated 'restored' from ['10.1021/np049863m', ['Plant Isolated']] to ['10.1021/np049863m', ['Plant Isolated']] for DOI ['10.1021/np049863m', 'Plant Isolated']
# 2024-10-04 13:30:02,732 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:02,738 - INFO - Updated 'restored' from ['10.1021/np060254j', ['Plant Isolated']] to ['10.1021/np060254j', ['Plant Isolated']] for DOI ['10.1021/np060254j', 'Plant Isolated']
# 2024-10-04 13:30:03,039 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:03,047 - INFO - Updated 'restored' from ['10.1021/np070312g', ['Plant Isolated']] to ['10.1021/np070312g', ['Plant Isolated']] for DOI ['10.1021/np070312g', 'Plant Isolated']
# 2024-10-04 13:30:03,228 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:03,237 - INFO - Updated 'restored' from ['10.1021/np100840w', ['Plant Isolated']] to ['10.1021/np100840w', ['Plant Isolated']] for DOI ['10.1021/np100840w', 'Plant Isolated']
# 2024-10-04 13:30:03,440 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:03,447 - INFO - Updated 'restored' from ['10.1021/np4006822', ['Microorganism isolated']] to ['10.1021/np4006822', ['Microorganism isolated']] for DOI ['10.1021/np4006822', 'Microorganism isolated']
# 2024-10-04 13:30:03,662 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:03,667 - INFO - Updated 'restored' from ['10.1021/np4006822', ['Microorganism isolated']] to ['10.1021/np4006822', ['Microorganism isolated']] for DOI ['10.1021/np4006822', 'Semisynthesis Product']
# 2024-10-04 13:30:03,963 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:03,970 - INFO - Updated 'restored' from ['10.1021/np500453x', ['Plant Isolated']] to ['10.1021/np500453x', ['Plant Isolated']] for DOI ['10.1021/np500453x', 'Plant Isolated']
# 2024-10-04 13:30:04,573 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:04,579 - INFO - Updated 'restored' from ['10.1021/np50086a012', ['Plant Isolated']] to ['10.1021/np50086a012', ['Plant Isolated']] for DOI ['10.1021/np50086a012', 'Plant Isolated']
# 2024-10-04 13:30:04,985 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:04,993 - INFO - Updated 'restored' from ['10.1021/np800106x', ['Plant Isolated']] to ['10.1021/np800106x', ['Plant Isolated']] for DOI ['10.1021/np800106x', 'Plant Isolated']
# 2024-10-04 13:30:05,801 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:05,895 - INFO - Updated 'restored' from ['10.1021/np9004079', ['Plant Isolated']] to ['10.1021/np9004079', ['Plant Isolated']] for DOI ['10.1021/np9004079', 'Plant Isolated']
# 2024-10-04 13:30:06,427 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:06,520 - INFO - Updated 'restored' from ['10.1021/np9703656', ['Plant Isolated']] to ['10.1021/np9703656', ['Plant Isolated']] for DOI ['10.1021/np9703656', 'Plant Isolated']
# 2024-10-04 13:30:06,925 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:06,932 - INFO - Updated 'restored' from ['10.1021/np9704617', ['Plant Isolated']] to ['10.1021/np9704617', ['Plant Isolated']] for DOI ['10.1021/np9704617', 'Plant Isolated']
# 2024-10-04 13:30:07,125 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:07,133 - INFO - Updated 'restored' from ['10.1055/s-0029-1185364', ['Plant Isolated']] to ['10.1055/s-0029-1185364', ['Plant Isolated']] for DOI ['10.1055/s-0029-1185364', 'Plant Isolated']
# 2024-10-04 13:30:07,441 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:07,445 - INFO - Updated 'restored' from ['10.1055/s-0034-1368301', ['Microorganism isolated']] to ['10.1055/s-0034-1368301', ['Microorganism isolated']] for DOI ['10.1055/s-0034-1368301', 'Microorganism isolated']
# 2024-10-04 13:30:08,110 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13
- INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:26,875 - INFO - Updated 'restored' from ['10.2174/187152010794728620', ['Plant Isolated']] to ['10.2174/187152010794728620', ['Plant Isolated']] for DOI ['10.2174/187152010794728620', 'Semisynthesis Product']
# 2024-10-04 13:30:27,307 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:27,314 - INFO - Updated 'restored' from ['10.2174/187152010794728620', ['Plant Isolated']] to ['10.2174/187152010794728620', ['Plant Isolated']] for DOI ['10.2174/187152010794728620', 'Plant Isolated']
# 2024-10-04 13:30:27,616 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:27,625 - INFO - Updated 'restored' from ['10.3390/molecules15129205', ['Plant Isolated']] to ['10.3390/molecules15129205', ['Plant Isolated']] for DOI ['10.3390/molecules15129205', 'Plant Isolated']
# 2024-10-04 13:30:27,819 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:27,828 - INFO - Updated 'restored' from ['10.3390/molecules190812031', ['Plant Isolated']] to ['10.3390/molecules190812031', ['Plant Isolated']] for DOI ['10.3390/molecules190812031', 'Plant Isolated']
# 2024-10-04 13:30:28,332 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:28,338 - INFO - Updated 'restored' from ['10.4067/S0717-97072009000300004', ['Plant Isolated']] to ['10.4067/S0717-97072009000300004', ['Plant Isolated']] for DOI ['10.4067/S0717-97072009000300004', 'Plant Isolated']
# 2024-10-04 13:30:28,556 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:28,563 - INFO - Updated 'restored' from ['10.5935/0100-4042.20140049', ['Plant Isolated']] to ['10.5935/0100-4042.20140049', ['Plant Isolated']] for DOI ['10.5935/0100-4042.20140049', 'Plant Isolated']
# 2024-10-04 13:30:28,945 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:29,055 - INFO - Updated 'restored' from ['10.5935/0103-5053.19930018', []] to ['10.5935/0103-5053.19930018', ['Plant Isolated']] for DOI ['10.5935/0103-5053.19930018', 'Plant Isolated']
# 2024-10-04 13:30:29,459 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-10-04 13:30:29,481 - INFO - Updated 'restored' from ['10.5935/0103-5053.19960024', []] to ['10.5935/0103-5053.19960024', ['Plant Isolated']] for DOI ['10.5935/0103-5053.19960024', 'Plant Isolated']
# 2024-10-04 13:30:29,484 - INFO - Updated file saved at llm_ft_results/llm_results_ft_4o_0.8_doi_collectionType_0_1st.csv
# Processing files: 100%|██████████| 1/1 [00:47<00:00, 47.06s/it]
# 2024-10-04 13:30:29,490 - INFO - Similarity search processing completed.

# %%
# Delete all files with _bak.csv as filename ending in the directory results/LLM_enhanced_full
backup_directory = 'results/LLM_corr_k_full'
for root, dirs, files in os.walk(backup_directory):
    for file in files:
        if file.endswith('.bak'):
            file_path = os.path.join(root, file)
            try:
                os.remove(file_path)
                logging.info(f"Deleted backup file: {file_path}")
            except Exception as e:
                logging.error(f"Error deleting file {file_path}: {e}")

# %%
#process doi_name files
import csv
import re
import os
import glob
import ast
import shutil

def process_csv(input_file, output_file):
    with open(input_file, 'r', newline='', encoding='utf-8') as infile, \
         open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile, quoting=csv.QUOTE_ALL)

        for row in reader:
            if reader.line_num == 1:
                writer.writerow(row)
                continue

            true_col, restored_col, edge_type = row

            # Process the true column
            true_col = process_column(true_col)

            # Process the restored column
            restored_col = process_column(restored_col)

            writer.writerow([true_col, restored_col, edge_type])

    print(f"Processed file saved as: {output_file}")

def process_column(col):
    try:
        # Remove outer brackets and split by the first comma
        content = col.strip()[1:-1]
        doi, name = content.split(',', 1)
        
        # Clean up DOI and name
        doi = doi.strip().strip("'\"")
        name = name.strip().strip("'\"")
        
        # Escape double quotes in the name
        name = name.replace('"', '\\"')
        
        # Reconstruct the column with proper quoting
        return f'["{doi}", "{name}"]'
    except:
        # If we can't parse it, return the original
        return col

def process_all_files(input_directory, output_directory):
    # Clean the output directory
    if os.path.exists(output_directory):
        shutil.rmtree(output_directory)
    os.makedirs(output_directory)

    # Pattern for matching file names
    pattern = r'processed_llm_results_gpt4_0.8_doi_name_\d+_\d+(?:st|nd|rd|th)\.csv'
    
    # Get all matching files in the input directory
    for input_file in glob.glob(os.path.join(input_directory, '*.csv')):
        if re.match(pattern, os.path.basename(input_file)):
            output_file = os.path.join(output_directory, os.path.basename(input_file))
            print(f"Processing {input_file}...")
            process_csv(input_file, output_file)

# Usage
input_directory = 'results/LLM_corr_k_full/'
output_directory = 'results/LLM_corr_k_full/modified_names/'
process_all_files(input_directory, output_directory)

# %%
# wrap the results in ' '
import os
import re

def process_file(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as infile:
        content = infile.read()
    
    def replace_function(match):
        doi = match.group(1)
        activities = match.group(2).split(', ')
        quoted_activities = []
        for i, activity in enumerate(activities):
            if i == 0:
                quoted_activities.append(f"{activity}'")
            elif i == len(activities) - 1:
                quoted_activities.append(f"'{activity}")
            else:
                quoted_activities.append(f"'{activity}'")
        return f"['{doi}', [{', '.join(quoted_activities)}]]"
    
    # Use regex to find and replace the specific part we want to change
    pattern = r"\['([^']+)', \[(.*?)\]\]"
    modified_content = re.sub(pattern, replace_function, content)
    
    with open(output_file, 'w', encoding='utf-8') as outfile:
        outfile.write(modified_content)

def process_folder(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            input_file = os.path.join(folder_path, filename)
            output_file = os.path.join(folder_path, f"processed_{filename}")
            process_file(input_file, output_file)
            print(f"Processed {filename}")

# Specify the folder path containing the CSV files
folder_path = 'results/LLM_corr_k_full'

# Process all CSV files in the folder
process_folder(folder_path)

# %%
#EVAL from NatUKE
import pandas as pd
from ast import literal_eval
import numpy as np

def hits_at(k, true, list_pred):
    hits = []
    for index_t, t in enumerate(true):
        hit = False
        # get the list of predicteds that's on the second argument
        for index_lp, lp in enumerate(list_pred[index_t][1]):
            if index_lp >= k:
                break
            if t[1] == lp:
                hits.append(1)
                hit = True
                break
        if not(hit):
            hits.append(0)
    return np.mean(hits)

def mrr(true, list_pred):
    # using the first list pred to get how many there will be
    rrs = []
    for index_t, t in enumerate(true):
        # get the list of predicteds that's on the second argument
        for index_lp, lp in enumerate(list_pred[index_t][1]):
            if t[1] == lp:
                rrs.append(1/(index_lp + 1))
                break
    return np.mean(rrs)


path = 'results/LLM_corr_k_full'
file_name = "llm_results"
splits = [0.8]
#edge_groups = ['doi_name', 'doi_bioActivity', 'doi_collectionSpecie', 'doi_collectionSite', 'doi_collectionType']
edge_group = 'doi_collectionSpecie'
#algorithms = ['bert', 'deep_walk', 'node2vec', 'metapath2vec', 'regularization']
algorithms = ['gpt4']
    #'collectionSpecie': 50,
    #'collectionSite': 20,
    #'bioActivity': 5,
    #'name': 50, -- DOESNT WORK HERE
    #'collectionType': 1
k_at = [1]
dynamic_stages = ['1st', '2nd', '3rd', '4th']

# hits@k
hitsatk_df = {'k': [], 'algorithm': [], 'edge_group': [], 'split': [], 'dynamic_stage': [], 'value': []}
for algorithm in algorithms:
    for k in k_at:
        for split in splits:
            for iteration in range(10):
                for dynamic_stage in dynamic_stages:
                    restored_df = pd.read_csv("{}/processed_{}_{}_{}_{}_{}_{}.csv".format(path, file_name, algorithm, split, edge_group, iteration, dynamic_stage))
                    restored_df['true'] = restored_df['true'].apply(literal_eval)
                    restored_df['restored'] = restored_df['restored'].apply(literal_eval)
                    hitsatk_df['k'].append(k)
                    hitsatk_df['algorithm'].append(algorithm)
                    hitsatk_df['split'].append(split)
                    hitsatk_df['edge_group'].append(edge_group)
                    hitsatk_df['dynamic_stage'].append(dynamic_stage)
                    hitsatk_df['value'].append(hits_at(k, restored_df.true.to_list(), restored_df.restored.to_list()))
                        
hitsatk_df = pd.DataFrame(hitsatk_df)
hitsatk_df.to_csv('{}/metric_results/full_dynamic_hits@k_{}_{}.csv'.format(path, edge_group, file_name), index=False)
hitsatk_df_mean = hitsatk_df.groupby(by=['k', 'algorithm', 'split', 'edge_group', 'dynamic_stage'], as_index=False).mean()
hitsatk_df_std = hitsatk_df.groupby(by=['k', 'algorithm', 'split', 'edge_group', 'dynamic_stage'], as_index=False).std()
hitsatk_df_mean['std'] = hitsatk_df_std['value']
print(hitsatk_df_mean)

# mrr
mrr_df = {'algorithm': [], 'edge_group': [], 'split': [], 'dynamic_stage': [], 'value': []}
for algorithm in algorithms:
    for split in splits:
        for iteration in range(10):
            for dynamic_stage in dynamic_stages:
                restored_df = pd.read_csv("{}/processed_{}_{}_{}_{}_{}_{}.csv".format(path, file_name, algorithm, split, edge_group, iteration, dynamic_stage))
                restored_df['true'] = restored_df['true'].apply(literal_eval)
                restored_df['restored'] = restored_df['restored'].apply(literal_eval)
                mrr_df['algorithm'].append(algorithm)
                mrr_df['split'].append(split)
                mrr_df['edge_group'].append(edge_group)
                mrr_df['dynamic_stage'].append(dynamic_stage)
                mrr_df['value'].append(mrr(restored_df.true.to_list(), restored_df.restored.to_list()))
                        
mrr_df = pd.DataFrame(mrr_df)
mrr_df.to_csv('{}/metric_results/full_dynamic_mrr_{}_{}.csv'.format(path, edge_group, file_name), index=False)
mrr_df_mean = mrr_df.groupby(by=['algorithm', 'edge_group', 'split', 'dynamic_stage'], as_index=False).mean()
mrr_df_std = mrr_df.groupby(by=['algorithm', 'edge_group', 'split', 'dynamic_stage'], as_index=False).std()
mrr_df_mean['std'] = mrr_df_std['value']
print(mrr_df_mean)

# saving files
hitsatk_df_mean.to_csv('{}/metric_results/dynamic_hits@k_{}_{}.csv'.format(path, edge_group, file_name), index=False)
mrr_df_mean.to_csv('{}/metric_results/dynamic_mrr_{}_{}.csv'.format(path, edge_group, file_name), index=False)

# %%
#EVAL from NatUKE -- for NAME
import pandas as pd
import numpy as np
import ast
import re

def parse_list(s):
    try:
        return ast.literal_eval(s)
    except:
        # If literal_eval fails, try a regex-based approach
        match = re.match(r'\[([^]]+)\]', s)
        if match:
            return [item.strip().strip('"') for item in match.group(1).split(',')]
        return []

def hits_at(k, true, list_pred):
    hits = []
    for t, p in zip(true, list_pred):
        if isinstance(p, list) and len(p) > 1:
            pred_list = p[1]
            if isinstance(pred_list, str):
                pred_list = parse_list(pred_list)
            hit = int(t[1] in pred_list[:k])
        else:
            hit = 0
        hits.append(hit)
    return np.mean(hits)

def mrr(true, list_pred):
    rrs = []
    for t, p in zip(true, list_pred):
        if isinstance(p, list) and len(p) > 1:
            pred_list = p[1]
            if isinstance(pred_list, str):
                pred_list = parse_list(pred_list)
            try:
                rank = pred_list.index(t[1]) + 1
                rrs.append(1 / rank)
            except ValueError:
                rrs.append(0)
        else:
            rrs.append(0)
    return np.mean(rrs)

path = 'results/LLM_corr_k_full'
file_name = "llm_results"
splits = [0.8]
edge_group = 'doi_name'
algorithms = ['gpt4']
k_at = [1]
dynamic_stages = ['1st', '2nd', '3rd', '4th']

# hits@k
hitsatk_df = {'k': [], 'algorithm': [], 'edge_group': [], 'split': [], 'dynamic_stage': [], 'value': []}
# mrr
mrr_df = {'algorithm': [], 'edge_group': [], 'split': [], 'dynamic_stage': [], 'value': []}

for algorithm in algorithms:
    for k in k_at:
        for split in splits:
            for iteration in range(10):
                for dynamic_stage in dynamic_stages:
                    file_path = f"{path}/fixed_names/processed_{file_name}_{algorithm}_{split}_{edge_group}_{iteration}_{dynamic_stage}.csv"
                    print(f"Processing file: {file_path}")
                    try:
                        restored_df = pd.read_csv(file_path)
                        restored_df['true'] = restored_df['true'].apply(parse_list)
                        restored_df['restored'] = restored_df['restored'].apply(parse_list)
                        
                        hits_value = hits_at(k, restored_df.true.to_list(), restored_df.restored.to_list())
                        mrr_value = mrr(restored_df.true.to_list(), restored_df.restored.to_list())
                        
                        print(f"Hits@{k}: {hits_value}")
                        print(f"MRR: {mrr_value}")
                        
                        hitsatk_df['k'].append(k)
                        hitsatk_df['algorithm'].append(algorithm)
                        hitsatk_df['split'].append(split)
                        hitsatk_df['edge_group'].append(edge_group)
                        hitsatk_df['dynamic_stage'].append(dynamic_stage)
                        hitsatk_df['value'].append(hits_value)

                        mrr_df['algorithm'].append(algorithm)
                        mrr_df['split'].append(split)
                        mrr_df['edge_group'].append(edge_group)
                        mrr_df['dynamic_stage'].append(dynamic_stage)
                        mrr_df['value'].append(mrr_value)
                    except Exception as e:
                        print(f"Error processing file {file_path}: {e}")
                        
hitsatk_df = pd.DataFrame(hitsatk_df)
hitsatk_df.to_csv('{}/metric_results/full_dynamic_hits@k_{}_{}.csv'.format(path, edge_group, file_name), index=False)
hitsatk_df_mean = hitsatk_df.groupby(by=['k', 'algorithm', 'split', 'edge_group', 'dynamic_stage'], as_index=False).mean()
hitsatk_df_std = hitsatk_df.groupby(by=['k', 'algorithm', 'split', 'edge_group', 'dynamic_stage'], as_index=False).std()
hitsatk_df_mean['std'] = hitsatk_df_std['value']
print(hitsatk_df_mean)

mrr_df = pd.DataFrame(mrr_df)
mrr_df.to_csv('{}/metric_results/full_dynamic_mrr_{}_{}.csv'.format(path, edge_group, file_name), index=False)
mrr_df_mean = mrr_df.groupby(by=['algorithm', 'edge_group', 'split', 'dynamic_stage'], as_index=False).mean()
mrr_df_std = mrr_df.groupby(by=['algorithm', 'edge_group', 'split', 'dynamic_stage'], as_index=False).std()
mrr_df_mean['std'] = mrr_df_std['value']
print(mrr_df_mean)

# saving files
hitsatk_df_mean.to_csv('{}/metric_results/dynamic_hits@k_{}_{}.csv'.format(path, edge_group, file_name), index=False)
mrr_df_mean.to_csv('{}/metric_results/dynamic_mrr_{}_{}.csv'.format(path, edge_group, file_name), index=False)

# %%
#finetune name fix
import os
import csv
import re
import ast
import shutil
from glob import glob
from tqdm import tqdm
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def fix_quotes(s):
    """
    Replace single quotes with double quotes, but not within words.
    """
    return re.sub(r"(?<!\w)'|'(?!\w)", '"', s)

def process_true_restored_field(cell):
    """
    Process the 'true' or 'restored' field to ensure it's a properly formatted list of strings.
    """
    try:
        # Attempt to parse the cell as a Python list
        parsed = ast.literal_eval(cell)
        if isinstance(parsed, list):
            # Ensure all elements are strings
            fixed = [str(item) for item in parsed]
            return str(fixed)
        else:
            # If not a list, treat it as a single string
            return f'["{str(parsed)}"]'
    except (ValueError, SyntaxError):
        # If parsing fails, attempt to fix quotes and reformat
        fixed_str = fix_quotes(cell)
        # Remove any leading/trailing whitespace and ensure it starts and ends with brackets
        fixed_str = fixed_str.strip()
        if not (fixed_str.startswith('[') and fixed_str.endswith(']')):
            fixed_str = f'[{fixed_str}]'
        # Split by comma, assuming the first comma separates DOI and name
        try:
            content = fixed_str[1:-1]
            doi, name = content.split(',', 1)
            doi = doi.strip().strip('"')
            name = name.strip().strip('"')
            # Escape any existing double quotes in the name
            name = name.replace('"', '\\"')
            return f'["{doi}", "{name}"]'
        except Exception as e:
            logging.error(f"Failed to process cell '{cell}': {e}")
            return cell  # Return the original cell if all else fails

def process_csv(input_file, output_file):
    """
    Process a single CSV file, fixing the 'true' and 'restored' columns.
    """
    with open(input_file, 'r', newline='', encoding='utf-8') as infile, \
         open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile, quoting=csv.QUOTE_ALL)
        
        for row in reader:
            if reader.line_num == 1:
                # Write header as is
                writer.writerow(row)
                continue
            
            try:
                true_col, restored_col, edge_type = row
            except ValueError:
                logging.warning(f"Unexpected number of columns in row {reader.line_num}: {row}")
                writer.writerow(row)
                continue
            
            # Process 'true' and 'restored' columns
            true_col_fixed = process_true_restored_field(true_col)
            restored_col_fixed = process_true_restored_field(restored_col)
            
            writer.writerow([true_col_fixed, restored_col_fixed, edge_type])
    
    logging.info(f"Processed file saved as: {output_file}")

def process_all_files(input_directory, output_directory):
    """
    Process all relevant CSV files in the input directory.
    """
    # Clean the output directory
    if os.path.exists(output_directory):
        shutil.rmtree(output_directory)
    os.makedirs(output_directory, exist_ok=True)
    
    # Define the pattern for 'name' CSV files
    pattern = r'llm_results_ft_4o_0\.8_doi_name_0_1st\.csv$'
    
    # Get all matching files in the input directory
    files = glob(os.path.join(input_directory, '*.csv'))
    name_files = [f for f in files if re.search(pattern, os.path.basename(f))]
    
    if not name_files:
        logging.warning(f"No 'name' CSV files found in directory '{input_directory}'.")
        return
    
    for input_file in tqdm(name_files, desc="Processing 'name' CSV files"):
        filename = os.path.basename(input_file)
        output_file = os.path.join(output_directory, filename)
        logging.info(f"Processing {filename}...")
        process_csv(input_file, output_file)

# Usage
if __name__ == "__main__":
    input_directory = 'llm_ft_results'  # Directory containing the original 'name' CSV files
    output_directory = 'llm_ft_results/processed_names'  # Directory to save the processed CSV files
    process_all_files(input_directory, output_directory)
# Out:
# Processing 'name' CSV files:   0%|          | 0/1 [00:00<?, ?it/s]2024-10-02 14:13:15,481 - INFO - Processing llm_results_ft_4o_0.8_doi_name_0_1st.csv...
# 2024-10-02 14:13:15,534 - INFO - Processed file saved as: llm_ft_results/processed_names/llm_results_ft_4o_0.8_doi_name_0_1st.csv
# Processing 'name' CSV files: 100%|██████████| 1/1 [00:00<00:00, 18.56it/s]

# %%
# eval for name
import pandas as pd
import numpy as np
import ast
import re
import os
from tqdm import tqdm

def parse_list(s):
    """
    Parse a string representation of a list into an actual Python list.
    """
    try:
        return ast.literal_eval(s)
    except (ValueError, SyntaxError):
        # Attempt to fix common formatting issues
        s = s.strip()
        if not (s.startswith('[') and s.endswith(']')):
            s = f'[{s}]'
        try:
            return ast.literal_eval(s)
        except:
            # As a last resort, split by comma
            return [item.strip().strip('"') for item in s.strip('[]').split(',')]

def hits_at(k, true, list_pred):
    """
    Calculate the Hits@k metric.
    """
    hits = []
    for t, p in zip(true, list_pred):
        if isinstance(p, list) and len(p) >= 2:
            pred_list = p[1]
            if isinstance(pred_list, str):
                pred_list = parse_list(pred_list)
            hit = int(t[1] in pred_list[:k])
        else:
            hit = 0
        hits.append(hit)
    return np.mean(hits)

def mrr(true, list_pred):
    """
    Calculate the Mean Reciprocal Rank (MRR) metric.
    """
    rrs = []
    for t, p in zip(true, list_pred):
        if isinstance(p, list) and len(p) >= 2:
            pred_list = p[1]
            if isinstance(pred_list, str):
                pred_list = parse_list(pred_list)
            try:
                rank = pred_list.index(t[1]) + 1
                rrs.append(1 / rank)
            except ValueError:
                rrs.append(0)
        else:
            rrs.append(0)
    return np.mean(rrs)

def evaluate_attribute(input_file, output_dir, attribute):
    """
    Evaluate the specified attribute using Hits@k and MRR metrics.
    """
    logging.info(f"Starting evaluation for attribute: {attribute}")
    
    try:
        restored_df = pd.read_csv(input_file)
    except FileNotFoundError:
        logging.error(f"The file {input_file} does not exist. Please check the path.")
        return
    except Exception as e:
        logging.error(f"Error reading {input_file}: {e}")
        return

    # Ensure 'true' and 'restored' columns exist
    if 'true' not in restored_df.columns or 'restored' not in restored_df.columns:
        logging.error(f"The input CSV must contain 'true' and 'restored' columns.")
        return

    # Parse 'true' and 'restored' columns
    restored_df['true'] = restored_df['true'].apply(parse_list)
    restored_df['restored'] = restored_df['restored'].apply(parse_list)
    
    # Extract lists
    true_values = restored_df['true'].to_list()  # List of tuples: [(doi, true_value), ...]
    predicted_values = restored_df['restored'].to_list()  # List of lists: [[doi, [pred1, pred2, ...]], ...]
    
    # Evaluation parameters
    k_at = [1, 3, 5, 10,25,50]  # You can adjust or extend these values
    
    # Initialize metrics storage
    hitsatk_records = []
    mrr_records = []
    
    # Calculate metrics
    for k in k_at:
        mean_hits = hits_at(k, true_values, predicted_values)
        hitsatk_records.append({
            'k': k,
            'metric': 'hits@k',
            'value': mean_hits
        })
        logging.info(f"Hits@{k}: {mean_hits}")
    
    mean_mrr = mrr(true_values, predicted_values)
    mrr_records.append({
        'metric': 'mrr',
        'value': mean_mrr
    })
    logging.info(f"MRR: {mean_mrr}")
    
    # Convert to DataFrames
    hitsatk_df = pd.DataFrame(hitsatk_records)
    mrr_df = pd.DataFrame(mrr_records)
    
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Save results
    hitsatk_output_path = os.path.join(output_dir, f'hits@k_{attribute}_evaluation.csv')
    mrr_output_path = os.path.join(output_dir, f'mrr_{attribute}_evaluation.csv')
    
    hitsatk_df.to_csv(hitsatk_output_path, index=False)
    mrr_df.to_csv(mrr_output_path, index=False)
    
    logging.info(f"Hits@k results saved to {hitsatk_output_path}")
    logging.info(f"MRR results saved to {mrr_output_path}")

# Usage
if __name__ == "__main__":
    import logging
    
    # Set up logging
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    
    # Define paths
    path = 'llm_ft_results'
    file_name = "llm_results_ft_4o_0.8_doi_name_0_1st.csv"
    name_csv_path = os.path.join(path, file_name)
    output_dir = 'ft_evaluation_results'
    attribute = 'name'  # Change to 'name' when processing 'name' attribute
    
    # Evaluate the attribute
    evaluate_attribute(name_csv_path, output_dir, attribute)
# Out:
# 2024-10-02 14:15:47,622 - INFO - Starting evaluation for attribute: name
# 2024-10-02 14:15:47,675 - INFO - Hits@1: 0.13031161473087818
# 2024-10-02 14:15:47,696 - INFO - Hits@3: 0.2521246458923513
# 2024-10-02 14:15:47,719 - INFO - Hits@5: 0.3002832861189802
# 2024-10-02 14:15:47,744 - INFO - Hits@10: 0.36827195467422097
# 2024-10-02 14:15:47,766 - INFO - Hits@25: 0.42209631728045327
# 2024-10-02 14:15:47,787 - INFO - Hits@50: 0.45042492917847027
# 2024-10-02 14:15:47,806 - INFO - MRR: 0.20809734957332549
# 2024-10-02 14:15:47,808 - INFO - Hits@k results saved to evaluation_results/hits@k_name_evaluation.csv
# 2024-10-02 14:15:47,809 - INFO - MRR results saved to evaluation_results/mrr_name_evaluation.csv
