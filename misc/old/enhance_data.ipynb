# %%
import csv
import ast
import os
import re

def remove_duplicates_from_restored(file_path):
    """
    Processes a CSV file to remove duplicate entries from the nested lists in the 'restored' column.

    Args:
        file_path (str): The path to the CSV file to be processed.
        
    The function reads the CSV file, processes each row to remove duplicates from the nested lists
    in the 'restored' column while preserving the first element and the order of subsequent elements.
    The modified data is then written back to the same file.
    """
    with open(file_path, mode='r+', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        fieldnames = reader.fieldnames
        rows = list(reader)
        
        file.seek(0)
        writer = csv.DictWriter(file, fieldnames=fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()
        
        for row in rows:
            restored = ast.literal_eval(row['restored'])
            if len(restored) > 1 and isinstance(restored[1], list):
                # Deduplicate the nested list while preserving the order
                deduplicated_list = list(dict.fromkeys(restored[1]))
                # Update the 'restored' field with the deduplicated list
                row['restored'] = str([restored[0], deduplicated_list])
            writer.writerow(row)
        
        file.truncate()

# Iterate through all files in the directory
directory = 'results/LLM_enhanced_complete/'
pattern = re.compile(r'llm_results_gpt4_0.8_doi_collectionSite_\d+_\d+(?:st|nd|rd|th)\.csv')

for filename in os.listdir(directory):
    if pattern.match(filename):
        file_path = os.path.join(directory, filename)
        remove_duplicates_from_restored(file_path)

# %%
import csv
import ast
import os
import re
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS

OPENAI_API_KEY = ''

embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
loaded_faiss_index = FAISS.load_local("faiss_index", embeddings, allow_dangerous_deserialization=True)

def clean_annotations(restored):
    # Remove rdflib.term.Literal annotations
    return [restored[0], [str(item).replace("rdflib.term.Literal(", "").replace(")", "") for item in restored[1]]]

def process_csv(file_path, faiss_index):
    print(f"Processing file: {file_path}")
    with open(file_path, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        fieldnames = reader.fieldnames
        rows = list(reader)
        
        for row in rows:
            restored = ast.literal_eval(row['restored'])
            print(f"Original restored: {restored}")
            if len(restored) > 1 and isinstance(restored[1], list):
                for i, result in enumerate(restored[1]):
                    print(f"Performing FAISS search for: {result}")
                    docs_with_score = faiss_index.similarity_search_with_score(result, top_k=1)
                    if docs_with_score:
                        top_result = docs_with_score[0][0].page_content
                        print(f"Top result: {top_result}")
                        restored[1][i] = top_result  # Ensure the result is a string
                restored = clean_annotations(restored)
                row['restored'] = str(restored)
                print(f"Updated restored: {row['restored']}")
    
    # Save the modified data to a new file
    new_file_path = file_path.replace('.csv', '_processed.csv')
    with open(new_file_path, mode='w', newline='', encoding='utf-8') as new_file:
        writer = csv.DictWriter(new_file, fieldnames=fieldnames, quoting=csv.QUOTE_ALL)
        writer.writeheader()
        writer.writerows(rows)
    print(f"Finished processing file. Results saved to: {new_file_path}")

# Iterate through all files in the directory
directory = 'results/LLM_enhanced/'
pattern = re.compile(r'llm_results_gpt4_0.8_doi_collectionSite_\d+_\d+(?:st|nd|rd|th)\.csv')

for filename in os.listdir(directory):
    if pattern.match(filename):
        file_path = os.path.join(directory, filename)
        process_csv(file_path, loaded_faiss_index)
# Out:
# Processing file: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_1_1st.csv
# Original restored: ['10.1002/cbdv.200590016', []]
# Updated restored: ['10.1002/cbdv.200590016', []]
# Original restored: ['10.1002/hlca.200890147', ['Apore, GO, Brazil']]
# Performing FAISS search for: Apore, GO, Brazil
# Top result: Apore ,GO
# Updated restored: ['10.1002/hlca.200890147', ['Apore ,GO']]
# Original restored: ['10.1002/jobm.200800093', ['Ribeirão Preto, State of São Paulo, Brazil']]
# Performing FAISS search for: Ribeirão Preto, State of São Paulo, Brazil
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1002/jobm.200800093', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1002/jobm.200800093', ['Ribeirão Preto, State of São Paulo, Brazil']]
# Performing FAISS search for: Ribeirão Preto, State of São Paulo, Brazil
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1002/jobm.200800093', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1002/ps.1278', ['Poços de Caldas, Minas Gerais, Brazil']]
# Performing FAISS search for: Poços de Caldas, Minas Gerais, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1002/ps.1278', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1002/ptr.1249', ['Ribeirão Preto, São Paulo']]
# Performing FAISS search for: Ribeirão Preto, São Paulo
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1002/ptr.1249', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1007/s10295-012-1165-2', ['Ribeirão Preto, Brazil', 'Mato Grosso do Sul State, Brazil']]
# Performing FAISS search for: Ribeirão Preto, Brazil
# Top result: Ribeirao Preto ,SP
# Performing FAISS search for: Mato Grosso do Sul State, Brazil
# Top result: Mato Grosso ,PB
# Updated restored: ['10.1007/s10295-012-1165-2', ['Ribeirao Preto ,SP', 'Mato Grosso ,PB']]
# Original restored: ['10.1007/s10295-012-1165-2', ['Ribeirão Preto, Brazil', 'Mato Grosso do Sul State, Brazil']]
# Performing FAISS search for: Ribeirão Preto, Brazil
# Top result: Ribeirao Preto ,SP
# Performing FAISS search for: Mato Grosso do Sul State, Brazil
# Top result: Mato Grosso ,PB
# Updated restored: ['10.1007/s10295-012-1165-2', ['Ribeirao Preto ,SP', 'Mato Grosso ,PB']]
# Original restored: ['10.1016/0031-9422(73)85048-4', ['Flooded banks of the Amazon river and its tributaries']]
# Performing FAISS search for: Flooded banks of the Amazon river and its tributaries
# Top result: Floresta Do Araguaia ,PA
# Updated restored: ['10.1016/0031-9422(73)85048-4', ['Floresta Do Araguaia ,PA']]
# Original restored: ['10.1016/0031-9422(90)80024-B', ['Minas Gerais, Brazil']]
# Performing FAISS search for: Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1016/0031-9422(90)80024-B', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1016/S0014-5793(02)02700-X', ['The geographical origin of the collection site is not specified in the provided text.']]
# Performing FAISS search for: The geographical origin of the collection site is not specified in the provided text.
# Top result: Materlandia ,MG
# Updated restored: ['10.1016/S0014-5793(02)02700-X', ['Materlandia ,MG']]
# Original restored: ['10.1016/S0031-9422(00)00225-9', ['Campininha Farm, Mogi-Guacu, SP, Brazil']]
# Performing FAISS search for: Campininha Farm, Mogi-Guacu, SP, Brazil
# Top result: Campestre ,MG
# Updated restored: ['10.1016/S0031-9422(00)00225-9', ['Campestre ,MG']]
# Original restored: ['10.1016/S0031-9422(00)00226-0', ['Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil', 'Campus do INPA, Manaus, Brazil']]
# Performing FAISS search for: Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil
# Top result: Teodoro Sampaio ,SP
# Performing FAISS search for: Campus do INPA, Manaus, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1016/S0031-9422(00)00226-0', ['Teodoro Sampaio ,SP', 'Manaus ,AM']]
# Original restored: ['10.1016/S0031-9422(00)00226-0', ['Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil', 'Campus do INPA, Manaus, Brazil']]
# Performing FAISS search for: Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil
# Top result: Teodoro Sampaio ,SP
# Performing FAISS search for: Campus do INPA, Manaus, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1016/S0031-9422(00)00226-0', ['Teodoro Sampaio ,SP', 'Manaus ,AM']]
# Original restored: ['10.1016/S0031-9422(00)00248-X', ['Espirito Santo, Brazil']]
# Performing FAISS search for: Espirito Santo, Brazil
# Top result: Espirito Santo ,RN
# Updated restored: ['10.1016/S0031-9422(00)00248-X', ['Espirito Santo ,RN']]
# Original restored: ['10.1016/S0031-9422(00)00323-X', ['San José de la Montaña, Costa Rica']]
# Performing FAISS search for: San José de la Montaña, Costa Rica
# Top result: Costa Rica ,MS
# Updated restored: ['10.1016/S0031-9422(00)00323-X', ['Costa Rica ,MS']]
# Original restored: ['10.1016/S0031-9422(00)00477-5', ['Amazon Forest, Mocambo, Paraense Emilio Goeldi Museum']]
# Performing FAISS search for: Amazon Forest, Mocambo, Paraense Emilio Goeldi Museum
# Top result: Piracanjuba ,GO
# Updated restored: ['10.1016/S0031-9422(00)00477-5', ['Piracanjuba ,GO']]
# Original restored: ['10.1016/S0031-9422(01)00079-6', ['Instituto Butantã Reserve, São Paulo']]
# Performing FAISS search for: Instituto Butantã Reserve, São Paulo
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1016/S0031-9422(01)00079-6', ['Sao Paulo ,SP']]
# Original restored: ['10.1016/S0031-9422(03)00153-5', ['Manaus, Brazil']]
# Performing FAISS search for: Manaus, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1016/S0031-9422(03)00153-5', ['Manaus ,AM']]
# Original restored: ['10.1016/S0031-9422(97)00598-0', ['São Carlos, SP, Brazil']]
# Performing FAISS search for: São Carlos, SP, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1016/S0031-9422(97)00598-0', ['Sao Carlos ,SP']]
# Original restored: ['10.1016/S0031-9422(98)00069-7', ['Corumba, Mato Grosso do Sul, Brazil']]
# Performing FAISS search for: Corumba, Mato Grosso do Sul, Brazil
# Top result: Corumba ,MS
# Updated restored: ['10.1016/S0031-9422(98)00069-7', ['Corumba ,MS']]
# Original restored: ['10.1016/S0031-9422(98)00249-0', ['São Paulo State, Brazil']]
# Performing FAISS search for: São Paulo State, Brazil
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1016/S0031-9422(98)00249-0', ['Sao Paulo ,SP']]
# Original restored: ['10.1016/S0031-9422(99)00132-6', ['Reserva da Ripasa, Ibate, SP, Brazil']]
# Performing FAISS search for: Reserva da Ripasa, Ibate, SP, Brazil
# Top result: Itapeva ,SP
# Updated restored: ['10.1016/S0031-9422(99)00132-6', ['Itapeva ,SP']]
# Original restored: ['10.1016/j.biortech.2010.01.041', ['Araraquara, SP, Brazil']]
# Performing FAISS search for: Araraquara, SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1016/j.biortech.2010.01.041', ['Araraquara ,SP']]
# Original restored: ['10.1016/j.bmc.2010.12.056', []]
# Updated restored: ['10.1016/j.bmc.2010.12.056', []]
# Original restored: ['10.1016/j.bse.2006.06.007', ['Araraquara, SP, Brazil']]
# Performing FAISS search for: Araraquara, SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1016/j.bse.2006.06.007', ['Araraquara ,SP']]
# Original restored: ['10.1016/j.cbi.2010.08.008', ['São Miguel Arcanjo, São Paulo, Brazil']]
# Performing FAISS search for: São Miguel Arcanjo, São Paulo, Brazil
# Top result: Sao Miguel Arcanjo ,SP
# Updated restored: ['10.1016/j.cbi.2010.08.008', ['Sao Miguel Arcanjo ,SP']]
# Original restored: ['10.1016/j.chroma.2009.02.009', ['Forest Reserve Adolpho Ducke, Itacoatiara, Amazonas state, Brazil']]
# Performing FAISS search for: Forest Reserve Adolpho Ducke, Itacoatiara, Amazonas state, Brazil
# Top result: Floresta Do Araguaia ,PA
# Updated restored: ['10.1016/j.chroma.2009.02.009', ['Floresta Do Araguaia ,PA']]
# Original restored: ['10.1016/j.chroma.2009.02.066', ['Estação Experimental de Citricultura do Instituto Agronômico de Campinas, Cordeirópolis, Brazil']]
# Performing FAISS search for: Estação Experimental de Citricultura do Instituto Agronômico de Campinas, Cordeirópolis, Brazil
# Top result: Campinas ,SP
# Updated restored: ['10.1016/j.chroma.2009.02.066', ['Campinas ,SP']]
# Original restored: ['10.1016/j.jchromb.2012.07.013', ['São Carlos, SP, Brazil']]
# Performing FAISS search for: São Carlos, SP, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1016/j.jchromb.2012.07.013', ['Sao Carlos ,SP']]
# Original restored: ['10.1016/j.jep.2007.09.020', ['Poços de Caldas, Minas Gerais State, Brazil']]
# Performing FAISS search for: Poços de Caldas, Minas Gerais State, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1016/j.jep.2007.09.020', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1016/j.jfca.2003.09.013', []]
# Updated restored: ['10.1016/j.jfca.2003.09.013', []]
# Original restored: ['10.1016/j.jpba.2012.08.028', []]
# Updated restored: ['10.1016/j.jpba.2012.08.028', []]
# Original restored: ['10.1016/j.jphotobiol.2013.01.006', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1016/j.jphotobiol.2013.01.006', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1016/j.phytochem.2004.03.039', ['Universidade Federal de Goiás, Goiânia, GO, Brazil']]
# Performing FAISS search for: Universidade Federal de Goiás, Goiânia, GO, Brazil
# Top result: Goiania ,GO
# Updated restored: ['10.1016/j.phytochem.2004.03.039', ['Goiania ,GO']]
# Original restored: ['10.1016/j.phytochem.2005.04.043', ['Associated with Ocotea corymbosa, Brazilian Cerrado']]
# Performing FAISS search for: Associated with Ocotea corymbosa, Brazilian Cerrado
# Top result: Carmo Do Cajuru ,MG
# Updated restored: ['10.1016/j.phytochem.2005.04.043', ['Carmo Do Cajuru ,MG']]
# Original restored: ['10.1016/j.phytochem.2006.06.004', ['Chemistry Institute UNESP – Araraquara, SP, Brazil']]
# Performing FAISS search for: Chemistry Institute UNESP – Araraquara, SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1016/j.phytochem.2006.06.004', ['Araraquara ,SP']]
# Original restored: ['10.1016/j.phytochem.2006.09.005', ['Brazilian Cerrado']]
# Performing FAISS search for: Brazilian Cerrado
# Top result: Guaracai ,SP
# Updated restored: ['10.1016/j.phytochem.2006.09.005', ['Guaracai ,SP']]
# Original restored: ['10.1016/j.phytochem.2007.08.012', ['Ibate – SP, Brazil']]
# Performing FAISS search for: Ibate – SP, Brazil
# Top result: Ibate ,SP
# Updated restored: ['10.1016/j.phytochem.2007.08.012', ['Ibate ,SP']]
# Original restored: ['10.1016/j.phytochem.2008.01.006', ['Botanic Garden of São Paulo, São Paulo State, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, São Paulo State, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1016/j.phytochem.2008.01.006', ['Jardinopolis ,SP']]
# Original restored: ['10.1016/j.phytochem.2009.08.013', ['São Sebastião da Posse city in Bahia State, Brazil']]
# Performing FAISS search for: São Sebastião da Posse city in Bahia State, Brazil
# Top result: Sao Sebastiao Do Passe ,BA
# Updated restored: ['10.1016/j.phytochem.2009.08.013', ['Sao Sebastiao Do Passe ,BA']]
# Original restored: ['10.1016/j.phytol.2010.11.003', ['Mogi-Guacu, Sao Paulo, Brazil']]
# Performing FAISS search for: Mogi-Guacu, Sao Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1016/j.phytol.2010.11.003', ['Mogi Guacu ,SP']]
# Original restored: ['10.1016/j.tiv.2008.01.003', ["Extracted from the dried and powdered root bark of M. ilicifolia'"]]
# Performing FAISS search for: Extracted from the dried and powdered root bark of M. ilicifolia'
# Top result: Ilicinea ,MG
# Updated restored: ['10.1016/j.tiv.2008.01.003', ['Ilicinea ,MG']]
# Original restored: ['10.1021/cc100076k', []]
# Updated restored: ['10.1021/cc100076k', []]
# Original restored: ['10.1021/cc100076k', []]
# Updated restored: ['10.1021/cc100076k', []]
# Original restored: ['10.1021/jf00030a035', ['São Paulo, São Carlos, and Rio de Janeiro, Brazil']]
# Performing FAISS search for: São Paulo, São Carlos, and Rio de Janeiro, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1021/jf00030a035', ['Sao Carlos ,SP']]
# Original restored: ['10.1021/jf100233y', ['Biological Reserve and Experimental Station at Mogi Guaçu, São Paulo State, Brazil']]
# Performing FAISS search for: Biological Reserve and Experimental Station at Mogi Guaçu, São Paulo State, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1021/jf100233y', ['Mogi Guacu ,SP']]
# Original restored: ['10.1021/jf60217a066', ['Northeast Brazil, specifically state of Ceará']]
# Performing FAISS search for: Northeast Brazil, specifically state of Ceará
# Top result: Guaraciaba Do Norte ,CE
# Updated restored: ['10.1021/jf60217a066', ['Guaraciaba Do Norte ,CE']]
# Original restored: ['10.1021/np0103970', ['Itajaí Valley, Santa Catarina, Brazil']]
# Performing FAISS search for: Itajaí Valley, Santa Catarina, Brazil
# Top result: Itajai ,SC
# Updated restored: ['10.1021/np0103970', ['Itajai ,SC']]
# Original restored: ['10.1021/np030100t', ['Campininha Farm, Mogi-Guacu, SP, Brazil']]
# Performing FAISS search for: Campininha Farm, Mogi-Guacu, SP, Brazil
# Top result: Campestre ,MG
# Updated restored: ['10.1021/np030100t', ['Campestre ,MG']]
# Original restored: ['10.1021/np0303963', ['Botanical Garden of the state of São Paulo, Brazil']]
# Performing FAISS search for: Botanical Garden of the state of São Paulo, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1021/np0303963', ['Jardinopolis ,SP']]
# Original restored: ['10.1021/np030530j', ['Campus of the Universidade de São Paulo, Brazil', 'Reserva Ripasa, Ibate, São Paulo, Brazil', 'Manaus, State of Amazonas, Brazil']]
# Performing FAISS search for: Campus of the Universidade de São Paulo, Brazil
# Top result: Campinas ,SP
# Performing FAISS search for: Reserva Ripasa, Ibate, São Paulo, Brazil
# Top result: Itapeva ,SP
# Performing FAISS search for: Manaus, State of Amazonas, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1021/np030530j', ['Campinas ,SP', 'Itapeva ,SP', 'Manaus ,AM']]
# Original restored: ['10.1021/np030530j', ['Campus of the Universidade de São Paulo, Brazil', 'Reserva Ripasa, Ibate, São Paulo, Brazil', 'Manaus, State of Amazonas, Brazil']]
# Performing FAISS search for: Campus of the Universidade de São Paulo, Brazil
# Top result: Campinas ,SP
# Performing FAISS search for: Reserva Ripasa, Ibate, São Paulo, Brazil
# Top result: Itapeva ,SP
# Performing FAISS search for: Manaus, State of Amazonas, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1021/np030530j', ['Campinas ,SP', 'Itapeva ,SP', 'Manaus ,AM']]
# Original restored: ['10.1021/np060254j', ['Rifaina, São Paulo, Brazil']]
# Performing FAISS search for: Rifaina, São Paulo, Brazil
# Top result: Rifaina ,SP
# Updated restored: ['10.1021/np060254j', ['Rifaina ,SP']]
# Original restored: ['10.1021/np070312g', ['Chemistry Institute at Sao Paulo State University (Araraquara-SP), Brazil']]
# Performing FAISS search for: Chemistry Institute at Sao Paulo State University (Araraquara-SP), Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1021/np070312g', ['Araraquara ,SP']]
# Original restored: ['10.1021/np100840w', ['Campinas municipality, São Paulo State, Brazil']]
# Performing FAISS search for: Campinas municipality, São Paulo State, Brazil
# Top result: Campinas ,SP
# Updated restored: ['10.1021/np100840w', ['Campinas ,SP']]
# Original restored: ['10.1021/np4006822', ['Federal University of Pernambuco, Brazil']]
# Performing FAISS search for: Federal University of Pernambuco, Brazil
# Top result: Recife ,PE
# Updated restored: ['10.1021/np4006822', ['Recife ,PE']]
# Original restored: ['10.1021/np500453x', ['Campinas, SP, Brazil']]
# Performing FAISS search for: Campinas, SP, Brazil
# Top result: Campinas ,SP
# Updated restored: ['10.1021/np500453x', ['Campinas ,SP']]
# Original restored: ['10.1021/np800612x', ['Botanic Garden of São Paulo, São Paulo State, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, São Paulo State, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1021/np800612x', ['Jardinopolis ,SP']]
# Original restored: ['10.1021/np9004079', ['Campinas municipality, São Paulo, Brazil']]
# Performing FAISS search for: Campinas municipality, São Paulo, Brazil
# Top result: Campinas ,SP
# Updated restored: ['10.1021/np9004079', ['Campinas ,SP']]
# Original restored: ['10.1021/np900644x', ['Araraquara, SP, Brazil']]
# Performing FAISS search for: Araraquara, SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1021/np900644x', ['Araraquara ,SP']]
# Original restored: ['10.1021/np9703656', ['Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil']]
# Performing FAISS search for: Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil
# Top result: Teodoro Sampaio ,SP
# Updated restored: ['10.1021/np9703656', ['Teodoro Sampaio ,SP']]
# Original restored: ['10.1021/np9704617', ['Campininha Farm, Mogi-Guacu, SP, Brazil']]
# Performing FAISS search for: Campininha Farm, Mogi-Guacu, SP, Brazil
# Top result: Campestre ,MG
# Updated restored: ['10.1021/np9704617', ['Campestre ,MG']]
# Original restored: ['10.1055/s-0028-1088323', ['São Carlos-SP, Brazil']]
# Performing FAISS search for: São Carlos-SP, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1055/s-0028-1088323', ['Sao Carlos ,SP']]
# Original restored: ['10.1055/s-0029-1185364', ['Poços de Caldas, MG, Brazil']]
# Performing FAISS search for: Poços de Caldas, MG, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1055/s-0029-1185364', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1055/s-0034-1368301', []]
# Updated restored: ['10.1055/s-0034-1368301', []]
# Original restored: ['10.1055/s-2002-36346', ['Araraquara/SP, Brazil']]
# Performing FAISS search for: Araraquara/SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1055/s-2002-36346', ['Araraquara ,SP']]
# Original restored: ['10.1080/14786410802243271', ['Vale do Ribeira, Atlantic Forest, São Paulo State, Brazil']]
# Performing FAISS search for: Vale do Ribeira, Atlantic Forest, São Paulo State, Brazil
# Top result: Ribeira ,SP
# Updated restored: ['10.1080/14786410802243271', ['Ribeira ,SP']]
# Original restored: ['10.1080/14786410903335232', ['Biological Reserve and Experimental Station at Mogi Guacu, Sao Paulo State, Brazil']]
# Performing FAISS search for: Biological Reserve and Experimental Station at Mogi Guacu, Sao Paulo State, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1080/14786410903335232', ['Mogi Guacu ,SP']]
# Original restored: ['10.1080/14786419.2011.647020', ['Minas Gerais, Brazil']]
# Performing FAISS search for: Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1080/14786419.2011.647020', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1107/S160053680302107X', ['Manaus-AM, Brazil']]
# Performing FAISS search for: Manaus-AM, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1107/S160053680302107X', ['Manaus ,AM']]
# Original restored: ['10.1155/2013/835081', ['Trachymyrmex ants, Brazil']]
# Performing FAISS search for: Trachymyrmex ants, Brazil
# Top result: Arantina ,MG
# Updated restored: ['10.1155/2013/835081', ['Arantina ,MG']]
# Original restored: ['10.1248/bpb.31.538', ['Araraquara-SP, Brazil']]
# Performing FAISS search for: Araraquara-SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1248/bpb.31.538', ['Araraquara ,SP']]
# Original restored: ['10.1248/cpb.56.407', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1248/cpb.56.407', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1248/cpb.56.723', ['Botanic Garden of São Paulo, SP, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, SP, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1248/cpb.56.723', ['Jardinopolis ,SP']]
# Original restored: ['10.1515/znb-2005-0715', ['Poc¸os D’antas, município de Murici, Alagoas state, Brazil']]
# Performing FAISS search for: Poc¸os D’antas, município de Murici, Alagoas state, Brazil
# Top result: Poco Das Antas ,RS
# Updated restored: ['10.1515/znb-2005-0715', ['Poco Das Antas ,RS']]
# Original restored: ['10.1515/znc-2002-5-602', ['Instituto Agronômico do Paraná, PR, Brazil']]
# Performing FAISS search for: Instituto Agronômico do Paraná, PR, Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1515/znc-2002-5-602', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1515/znc-2002-5-602', ['Instituto Agronômico do Paraná, PR, Brazil']]
# Performing FAISS search for: Instituto Agronômico do Paraná, PR, Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1515/znc-2002-5-602', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1515/znc-2008-5-611', ['Poc¸os de Caldas, Minas Gerais, Brazil']]
# Performing FAISS search for: Poc¸os de Caldas, Minas Gerais, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1515/znc-2008-5-611', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1515/znc-2009-11-1212', ['Estação Ecológica Experimental de Mogi-Guaçu, Fazenda Campininha, Mogi-Guaçu, São Paulo, Brazil']]
# Performing FAISS search for: Estação Ecológica Experimental de Mogi-Guaçu, Fazenda Campininha, Mogi-Guaçu, São Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1515/znc-2009-11-1212', ['Mogi Guacu ,SP']]
# Original restored: ['10.1515/znc-2011-5-607', ['Universidade Federal de Viçosa, Viçosa, MG, Brazil', 'Extracted arillus supplied by Cognis Brasil Ltda., São Paulo, SP, Brazil']]
# Performing FAISS search for: Universidade Federal de Viçosa, Viçosa, MG, Brazil
# Top result: Uberaba ,MG
# Performing FAISS search for: Extracted arillus supplied by Cognis Brasil Ltda., São Paulo, SP, Brazil
# Top result: Ararica ,RS
# Updated restored: ['10.1515/znc-2011-5-607', ['Uberaba ,MG', 'Ararica ,RS']]
# Original restored: ['10.1590/S0073-47212009000100009', []]
# Updated restored: ['10.1590/S0073-47212009000100009', []]
# Original restored: ['10.1590/S0100-40421998000600005', ['Santarém, state of Pará, Brazil']]
# Performing FAISS search for: Santarém, state of Pará, Brazil
# Top result: Santarem ,PA
# Updated restored: ['10.1590/S0100-40421998000600005', ['Santarem ,PA']]
# Original restored: ['10.1590/S0100-40422002000300002', ['Estação Ecológica e Experimental de Mogi-Guaçu-SP, Brazil']]
# Performing FAISS search for: Estação Ecológica e Experimental de Mogi-Guaçu-SP, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1590/S0100-40422002000300002', ['Mogi Guacu ,SP']]
# Original restored: ['10.1590/S0100-40422004000200005', ['Reserva Ecológica de Cunha, São Paulo, Brazil']]
# Performing FAISS search for: Reserva Ecológica de Cunha, São Paulo, Brazil
# Top result: Cunha ,SP
# Updated restored: ['10.1590/S0100-40422004000200005', ['Cunha ,SP']]
# Original restored: ['10.1590/S0100-40422005000600011', ['Estação Ecológica Experimental de Mogi-Guaçú, São Paulo, Brazil']]
# Performing FAISS search for: Estação Ecológica Experimental de Mogi-Guaçú, São Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1590/S0100-40422005000600011', ['Mogi Guacu ,SP']]
# Original restored: ['10.1590/S0100-40422008000400005', []]
# Updated restored: ['10.1590/S0100-40422008000400005', []]
# Original restored: ['10.1590/S0100-40422008000400005', []]
# Updated restored: ['10.1590/S0100-40422008000400005', []]
# Original restored: ['10.1590/S0100-40422008000400005', []]
# Updated restored: ['10.1590/S0100-40422008000400005', []]
# Original restored: ['10.1590/S0100-40422008000400018', ['Instituto de Botânica, São Paulo – SP']]
# Performing FAISS search for: Instituto de Botânica, São Paulo – SP
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1590/S0100-40422008000400018', ['Sao Paulo ,SP']]
# Original restored: ['10.1590/S0100-40422009000600037', ["Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)"]]
# Performing FAISS search for: Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)
# Top result: Piracicaba ,SP
# Updated restored: ['10.1590/S0100-40422009000600037', ['Piracicaba ,SP']]
# Original restored: ['10.1590/S0100-40422010001000006', ['Araraquara – SP, Brazil']]
# Performing FAISS search for: Araraquara – SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1590/S0100-40422010001000006', ['Araraquara ,SP']]
# Original restored: ['10.1590/S0100-40422012000700020', ['Anápolis-Goiás, Brazil']]
# Performing FAISS search for: Anápolis-Goiás, Brazil
# Top result: Divinopolis De Goias ,GO
# Updated restored: ['10.1590/S0100-40422012000700020', ['Divinopolis De Goias ,GO']]
# Original restored: ['10.1590/S0100-46702007000300002', ['Campus da Universidade de São Paulo (USP), Ribeirão Preto, São Paulo, Brasil']]
# Performing FAISS search for: Campus da Universidade de São Paulo (USP), Ribeirão Preto, São Paulo, Brasil
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1590/S0100-46702007000300002', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1590/S0102-695X2007000300003', ['Juréia Reserve, São Paulo, Brazil']]
# Performing FAISS search for: Juréia Reserve, São Paulo, Brazil
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1590/S0102-695X2007000300003', ['Sao Paulo ,SP']]
# Original restored: ['10.1590/S0102-695X2008000200010', ['Lavras, State of Minas Gerais, Brazil']]
# Performing FAISS search for: Lavras, State of Minas Gerais, Brazil
# Top result: Lavras ,MG
# Updated restored: ['10.1590/S0102-695X2008000200010', ['Lavras ,MG']]
# Original restored: ['10.1590/S0102-695X2009000100002', ['Viçosa, Minas Gerais, Brazil']]
# Performing FAISS search for: Viçosa, Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1590/S0102-695X2009000100002', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1590/S0102-695X2010000100002', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1590/S0102-695X2010000100002', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1590/S0102-695X2010005000017', ['Botanic Garden of São Paulo, São Paulo, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, São Paulo, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1590/S0102-695X2010005000017', ['Jardinopolis ,SP']]
# Original restored: ['10.1590/S0102-695X2012005000106', []]
# Updated restored: ['10.1590/S0102-695X2012005000106', []]
# Original restored: ['10.1590/S0103-50532002000100010', ['Ressacada, Ibirama, SC, Brazil']]
# Performing FAISS search for: Ressacada, Ibirama, SC, Brazil
# Top result: Ibirama ,SC
# Updated restored: ['10.1590/S0103-50532002000100010', ['Ibirama ,SC']]
# Original restored: ['10.1590/S0103-50532002000100019', ['Rio Claro, São Paulo state, Brazil']]
# Performing FAISS search for: Rio Claro, São Paulo state, Brazil
# Top result: Rio Claro ,SP
# Updated restored: ['10.1590/S0103-50532002000100019', ['Rio Claro ,SP']]
# Original restored: ['10.1590/S0103-50532003000300007', ['Bahia, Brazil', 'Brazil']]
# Performing FAISS search for: Bahia, Brazil
# Top result: Pirai Do Norte ,BA
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1590/S0103-50532003000300007', ['Pirai Do Norte ,BA', 'Brasilandia Do Sul ,PR']]
# Original restored: ['10.1590/S0103-50532003000500012', ['Reserva do Viro, Belém - PA, Brazil']]
# Performing FAISS search for: Reserva do Viro, Belém - PA, Brazil
# Top result: Brasil Novo ,PA
# Updated restored: ['10.1590/S0103-50532003000500012', ['Brasil Novo ,PA']]
# Original restored: ['10.1590/S0103-50532005000300018', ['Espírito Santo State, southeast of Brazil']]
# Performing FAISS search for: Espírito Santo State, southeast of Brazil
# Top result: Espirito Santo ,RN
# Updated restored: ['10.1590/S0103-50532005000300018', ['Espirito Santo ,RN']]
# Original restored: ['10.1590/S0103-50532005000400005', ['Atlantic Forest, Brazil']]
# Performing FAISS search for: Atlantic Forest, Brazil
# Top result: Floresta Do Araguaia ,PA
# Updated restored: ['10.1590/S0103-50532005000400005', ['Floresta Do Araguaia ,PA']]
# Original restored: ['10.1590/S0103-50532005000800008', ['Belém, Pará State, Brazil']]
# Performing FAISS search for: Belém, Pará State, Brazil
# Top result: Belem ,PB
# Updated restored: ['10.1590/S0103-50532005000800008', ['Belem ,PB']]
# Original restored: ['10.1590/S0103-50532005000800025', ['Ressacada, Ibirama, SC, Brazil']]
# Performing FAISS search for: Ressacada, Ibirama, SC, Brazil
# Top result: Ibirama ,SC
# Updated restored: ['10.1590/S0103-50532005000800025', ['Ibirama ,SC']]
# Original restored: ['10.1590/S0103-50532005000800026', ['Pantanal - MS, Brazil']]
# Performing FAISS search for: Pantanal - MS, Brazil
# Top result: Brasilandia ,MS
# Updated restored: ['10.1590/S0103-50532005000800026', ['Brasilandia ,MS']]
# Original restored: ['10.1590/S0103-50532005000800029', ['Araraquara, São Paulo, Brazil']]
# Performing FAISS search for: Araraquara, São Paulo, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1590/S0103-50532005000800029', ['Araraquara ,SP']]
# Original restored: ['10.1590/S0103-50532006000300017', ['São Carlos-SP, Brazil', 'Belém, Pará, Brazil']]
# Performing FAISS search for: São Carlos-SP, Brazil
# Top result: Sao Carlos ,SP
# Performing FAISS search for: Belém, Pará, Brazil
# Top result: Belem ,PA
# Updated restored: ['10.1590/S0103-50532006000300017', ['Sao Carlos ,SP', 'Belem ,PA']]
# Original restored: ['10.1590/S0103-50532007000700017', ['Estação Ecológica e Experimental de Mogi-Guaçu, São Paulo, Brazil']]
# Performing FAISS search for: Estação Ecológica e Experimental de Mogi-Guaçu, São Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1590/S0103-50532007000700017', ['Mogi Guacu ,SP']]
# Original restored: ['10.1590/S0103-50532009000100029', []]
# Updated restored: ['10.1590/S0103-50532009000100029', []]
# Original restored: ['10.1590/S0103-50532009000400008', ['Campinas (SP) at the Instituto Agronômico de Campinas']]
# Performing FAISS search for: Campinas (SP) at the Instituto Agronômico de Campinas
# Top result: Campinas ,SP
# Updated restored: ['10.1590/S0103-50532009000400008', ['Campinas ,SP']]
# Original restored: ['10.1590/S1519-566X2008000600013', []]
# Updated restored: ['10.1590/S1519-566X2008000600013', []]
# Original restored: ['10.1590/s0100-40422008000700015', ['Not specified']]
# Performing FAISS search for: Not specified
# Top result: N/A,TO
# Updated restored: ['10.1590/s0100-40422008000700015', ['N/A,TO']]
# Original restored: ['10.2174/187152010794728620', ['not specified', 'Federal University of Viçosa, MG, Brazil', 'Belém, Pará State, Brazil']]
# Performing FAISS search for: not specified
# Top result: N/A,TO
# Performing FAISS search for: Federal University of Viçosa, MG, Brazil
# Top result: Santa Vitoria ,MG
# Performing FAISS search for: Belém, Pará State, Brazil
# Top result: Belem ,PB
# Updated restored: ['10.2174/187152010794728620', ['N/A,TO', 'Santa Vitoria ,MG', 'Belem ,PB']]
# Original restored: ['10.3390/molecules15129205', ['São Paulo State, Brazil']]
# Performing FAISS search for: São Paulo State, Brazil
# Top result: Sao Paulo ,SP
# Updated restored: ['10.3390/molecules15129205', ['Sao Paulo ,SP']]
# Original restored: ['10.3390/molecules190812031', ['Amazon state, Brazil']]
# Performing FAISS search for: Amazon state, Brazil
# Top result: Porto Amazonas ,PR
# Updated restored: ['10.3390/molecules190812031', ['Porto Amazonas ,PR']]
# Original restored: ['10.5935/0100-4042.20140049', ['Serra dos Pirineus, Pirenópolis - GO, Brazil']]
# Performing FAISS search for: Serra dos Pirineus, Pirenópolis - GO, Brazil
# Top result: Pirenopolis ,GO
# Updated restored: ['10.5935/0100-4042.20140049', ['Pirenopolis ,GO']]
# Original restored: ['10.5935/0103-5053.19930018', []]
# Updated restored: ['10.5935/0103-5053.19930018', []]
# Original restored: ['10.5935/0103-5053.19960024', []]
# Updated restored: ['10.5935/0103-5053.19960024', []]
# Finished processing file. Results saved to: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_1_1st_processed.csv
# Processing file: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_1_3rd.csv
# Original restored: ['10.1002/cbdv.200590016', []]
# Updated restored: ['10.1002/cbdv.200590016', []]
# Original restored: ['10.1002/ps.1278', ['Poços de Caldas, Minas Gerais, Brazil']]
# Performing FAISS search for: Poços de Caldas, Minas Gerais, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1002/ps.1278', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1007/s10295-012-1165-2', ['Ribeirão Preto, Brazil', 'Mato Grosso do Sul State, Brazil']]
# Performing FAISS search for: Ribeirão Preto, Brazil
# Top result: Ribeirao Preto ,SP
# Performing FAISS search for: Mato Grosso do Sul State, Brazil
# Top result: Mato Grosso ,PB
# Updated restored: ['10.1007/s10295-012-1165-2', ['Ribeirao Preto ,SP', 'Mato Grosso ,PB']]
# Original restored: ['10.1007/s10295-012-1165-2', ['Ribeirão Preto, Brazil', 'Mato Grosso do Sul State, Brazil']]
# Performing FAISS search for: Ribeirão Preto, Brazil
# Top result: Ribeirao Preto ,SP
# Performing FAISS search for: Mato Grosso do Sul State, Brazil
# Top result: Mato Grosso ,PB
# Updated restored: ['10.1007/s10295-012-1165-2', ['Ribeirao Preto ,SP', 'Mato Grosso ,PB']]
# Original restored: ['10.1016/S0014-5793(02)02700-X', ['The geographical origin of the collection site is not specified in the provided text.']]
# Performing FAISS search for: The geographical origin of the collection site is not specified in the provided text.
# Top result: Materlandia ,MG
# Updated restored: ['10.1016/S0014-5793(02)02700-X', ['Materlandia ,MG']]
# Original restored: ['10.1016/S0031-9422(00)00477-5', ['Amazon Forest, Mocambo, Paraense Emilio Goeldi Museum']]
# Performing FAISS search for: Amazon Forest, Mocambo, Paraense Emilio Goeldi Museum
# Top result: Piracanjuba ,GO
# Updated restored: ['10.1016/S0031-9422(00)00477-5', ['Piracanjuba ,GO']]
# Original restored: ['10.1016/S0031-9422(98)00069-7', ['Corumba, Mato Grosso do Sul, Brazil']]
# Performing FAISS search for: Corumba, Mato Grosso do Sul, Brazil
# Top result: Corumba ,MS
# Updated restored: ['10.1016/S0031-9422(98)00069-7', ['Corumba ,MS']]
# Original restored: ['10.1016/j.chroma.2009.02.009', ['Forest Reserve Adolpho Ducke, Itacoatiara, Amazonas state, Brazil']]
# Performing FAISS search for: Forest Reserve Adolpho Ducke, Itacoatiara, Amazonas state, Brazil
# Top result: Floresta Do Araguaia ,PA
# Updated restored: ['10.1016/j.chroma.2009.02.009', ['Floresta Do Araguaia ,PA']]
# Original restored: ['10.1016/j.jchromb.2012.07.013', ['São Carlos, SP, Brazil']]
# Performing FAISS search for: São Carlos, SP, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1016/j.jchromb.2012.07.013', ['Sao Carlos ,SP']]
# Original restored: ['10.1016/j.jep.2007.09.020', ['Poços de Caldas, Minas Gerais State, Brazil']]
# Performing FAISS search for: Poços de Caldas, Minas Gerais State, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1016/j.jep.2007.09.020', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1016/j.jfca.2003.09.013', []]
# Updated restored: ['10.1016/j.jfca.2003.09.013', []]
# Original restored: ['10.1016/j.jpba.2012.08.028', []]
# Updated restored: ['10.1016/j.jpba.2012.08.028', []]
# Original restored: ['10.1016/j.jphotobiol.2013.01.006', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1016/j.jphotobiol.2013.01.006', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1016/j.phytochem.2006.06.004', ['Chemistry Institute UNESP – Araraquara, SP, Brazil']]
# Performing FAISS search for: Chemistry Institute UNESP – Araraquara, SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1016/j.phytochem.2006.06.004', ['Araraquara ,SP']]
# Original restored: ['10.1016/j.phytochem.2006.09.005', ['Brazilian Cerrado']]
# Performing FAISS search for: Brazilian Cerrado
# Top result: Guaracai ,SP
# Updated restored: ['10.1016/j.phytochem.2006.09.005', ['Guaracai ,SP']]
# Original restored: ['10.1016/j.phytochem.2007.08.012', ['Ibate – SP, Brazil']]
# Performing FAISS search for: Ibate – SP, Brazil
# Top result: Ibate ,SP
# Updated restored: ['10.1016/j.phytochem.2007.08.012', ['Ibate ,SP']]
# Original restored: ['10.1016/j.phytochem.2009.08.013', ['São Sebastião da Posse city in Bahia State, Brazil']]
# Performing FAISS search for: São Sebastião da Posse city in Bahia State, Brazil
# Top result: Sao Sebastiao Do Passe ,BA
# Updated restored: ['10.1016/j.phytochem.2009.08.013', ['Sao Sebastiao Do Passe ,BA']]
# Original restored: ['10.1016/j.tiv.2008.01.003', ["Extracted from the dried and powdered root bark of M. ilicifolia'"]]
# Performing FAISS search for: Extracted from the dried and powdered root bark of M. ilicifolia'
# Top result: Ilicinea ,MG
# Updated restored: ['10.1016/j.tiv.2008.01.003', ['Ilicinea ,MG']]
# Original restored: ['10.1021/jf00030a035', ['São Paulo, São Carlos, and Rio de Janeiro, Brazil']]
# Performing FAISS search for: São Paulo, São Carlos, and Rio de Janeiro, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1021/jf00030a035', ['Sao Carlos ,SP']]
# Original restored: ['10.1021/jf60217a066', ['Northeast Brazil, specifically state of Ceará']]
# Performing FAISS search for: Northeast Brazil, specifically state of Ceará
# Top result: Guaraciaba Do Norte ,CE
# Updated restored: ['10.1021/jf60217a066', ['Guaraciaba Do Norte ,CE']]
# Original restored: ['10.1021/np0303963', ['Botanical Garden of the state of São Paulo, Brazil']]
# Performing FAISS search for: Botanical Garden of the state of São Paulo, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1021/np0303963', ['Jardinopolis ,SP']]
# Original restored: ['10.1021/np4006822', ['Federal University of Pernambuco, Brazil']]
# Performing FAISS search for: Federal University of Pernambuco, Brazil
# Top result: Recife ,PE
# Updated restored: ['10.1021/np4006822', ['Recife ,PE']]
# Original restored: ['10.1021/np9004079', ['Campinas municipality, São Paulo, Brazil']]
# Performing FAISS search for: Campinas municipality, São Paulo, Brazil
# Top result: Campinas ,SP
# Updated restored: ['10.1021/np9004079', ['Campinas ,SP']]
# Original restored: ['10.1021/np900644x', ['Araraquara, SP, Brazil']]
# Performing FAISS search for: Araraquara, SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1021/np900644x', ['Araraquara ,SP']]
# Original restored: ['10.1021/np9703656', ['Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil']]
# Performing FAISS search for: Parque Estadual do Morro do Diabo, Teodoro Sampaio, SP, Brazil
# Top result: Teodoro Sampaio ,SP
# Updated restored: ['10.1021/np9703656', ['Teodoro Sampaio ,SP']]
# Original restored: ['10.1055/s-0028-1088323', ['São Carlos-SP, Brazil']]
# Performing FAISS search for: São Carlos-SP, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1055/s-0028-1088323', ['Sao Carlos ,SP']]
# Original restored: ['10.1055/s-2002-36346', ['Araraquara/SP, Brazil']]
# Performing FAISS search for: Araraquara/SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1055/s-2002-36346', ['Araraquara ,SP']]
# Original restored: ['10.1080/14786410903335232', ['Biological Reserve and Experimental Station at Mogi Guacu, Sao Paulo State, Brazil']]
# Performing FAISS search for: Biological Reserve and Experimental Station at Mogi Guacu, Sao Paulo State, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1080/14786410903335232', ['Mogi Guacu ,SP']]
# Original restored: ['10.1248/cpb.56.407', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1248/cpb.56.407', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1248/cpb.56.723', ['Botanic Garden of São Paulo, SP, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, SP, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1248/cpb.56.723', ['Jardinopolis ,SP']]
# Original restored: ['10.1515/znb-2005-0715', ['Poc¸os D’antas, município de Murici, Alagoas state, Brazil']]
# Performing FAISS search for: Poc¸os D’antas, município de Murici, Alagoas state, Brazil
# Top result: Poco Das Antas ,RS
# Updated restored: ['10.1515/znb-2005-0715', ['Poco Das Antas ,RS']]
# Original restored: ['10.1515/znc-2008-5-611', ['Poc¸os de Caldas, Minas Gerais, Brazil']]
# Performing FAISS search for: Poc¸os de Caldas, Minas Gerais, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1515/znc-2008-5-611', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1515/znc-2009-11-1212', ['Estação Ecológica Experimental de Mogi-Guaçu, Fazenda Campininha, Mogi-Guaçu, São Paulo, Brazil']]
# Performing FAISS search for: Estação Ecológica Experimental de Mogi-Guaçu, Fazenda Campininha, Mogi-Guaçu, São Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1515/znc-2009-11-1212', ['Mogi Guacu ,SP']]
# Original restored: ['10.1515/znc-2011-5-607', ['Universidade Federal de Viçosa, Viçosa, MG, Brazil', 'Extracted arillus supplied by Cognis Brasil Ltda., São Paulo, SP, Brazil']]
# Performing FAISS search for: Universidade Federal de Viçosa, Viçosa, MG, Brazil
# Top result: Uberaba ,MG
# Performing FAISS search for: Extracted arillus supplied by Cognis Brasil Ltda., São Paulo, SP, Brazil
# Top result: Ararica ,RS
# Updated restored: ['10.1515/znc-2011-5-607', ['Uberaba ,MG', 'Ararica ,RS']]
# Original restored: ['10.1590/S0073-47212009000100009', []]
# Updated restored: ['10.1590/S0073-47212009000100009', []]
# Original restored: ['10.1590/S0100-40422004000200005', ['Reserva Ecológica de Cunha, São Paulo, Brazil']]
# Performing FAISS search for: Reserva Ecológica de Cunha, São Paulo, Brazil
# Top result: Cunha ,SP
# Updated restored: ['10.1590/S0100-40422004000200005', ['Cunha ,SP']]
# Original restored: ['10.1590/S0100-40422005000600011', ['Estação Ecológica Experimental de Mogi-Guaçú, São Paulo, Brazil']]
# Performing FAISS search for: Estação Ecológica Experimental de Mogi-Guaçú, São Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1590/S0100-40422005000600011', ['Mogi Guacu ,SP']]
# Original restored: ['10.1590/S0100-40422008000400005', []]
# Updated restored: ['10.1590/S0100-40422008000400005', []]
# Original restored: ['10.1590/S0100-40422008000400005', []]
# Updated restored: ['10.1590/S0100-40422008000400005', []]
# Original restored: ['10.1590/S0100-40422008000400005', []]
# Updated restored: ['10.1590/S0100-40422008000400005', []]
# Original restored: ['10.1590/S0100-40422008000400018', ['Instituto de Botânica, São Paulo – SP']]
# Performing FAISS search for: Instituto de Botânica, São Paulo – SP
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1590/S0100-40422008000400018', ['Sao Paulo ,SP']]
# Original restored: ['10.1590/S0100-40422009000600037', ["Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)"]]
# Performing FAISS search for: Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)
# Top result: Piracicaba ,SP
# Updated restored: ['10.1590/S0100-40422009000600037', ['Piracicaba ,SP']]
# Original restored: ['10.1590/S0100-40422010001000006', ['Araraquara – SP, Brazil']]
# Performing FAISS search for: Araraquara – SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1590/S0100-40422010001000006', ['Araraquara ,SP']]
# Original restored: ['10.1590/S0102-695X2008000200010', ['Lavras, State of Minas Gerais, Brazil']]
# Performing FAISS search for: Lavras, State of Minas Gerais, Brazil
# Top result: Lavras ,MG
# Updated restored: ['10.1590/S0102-695X2008000200010', ['Lavras ,MG']]
# Original restored: ['10.1590/S0102-695X2009000100002', ['Viçosa, Minas Gerais, Brazil']]
# Performing FAISS search for: Viçosa, Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1590/S0102-695X2009000100002', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1590/S0103-50532002000100010', ['Ressacada, Ibirama, SC, Brazil']]
# Performing FAISS search for: Ressacada, Ibirama, SC, Brazil
# Top result: Ibirama ,SC
# Updated restored: ['10.1590/S0103-50532002000100010', ['Ibirama ,SC']]
# Original restored: ['10.1590/S0103-50532003000500012', ['Reserva do Viro, Belém - PA, Brazil']]
# Performing FAISS search for: Reserva do Viro, Belém - PA, Brazil
# Top result: Brasil Novo ,PA
# Updated restored: ['10.1590/S0103-50532003000500012', ['Brasil Novo ,PA']]
# Original restored: ['10.1590/S0103-50532005000300018', ['Espírito Santo State, southeast of Brazil']]
# Performing FAISS search for: Espírito Santo State, southeast of Brazil
# Top result: Espirito Santo ,RN
# Updated restored: ['10.1590/S0103-50532005000300018', ['Espirito Santo ,RN']]
# Original restored: ['10.1590/S0103-50532005000400005', ['Atlantic Forest, Brazil']]
# Performing FAISS search for: Atlantic Forest, Brazil
# Top result: Floresta Do Araguaia ,PA
# Updated restored: ['10.1590/S0103-50532005000400005', ['Floresta Do Araguaia ,PA']]
# Original restored: ['10.1590/S0103-50532005000800025', ['Ressacada, Ibirama, SC, Brazil']]
# Performing FAISS search for: Ressacada, Ibirama, SC, Brazil
# Top result: Ibirama ,SC
# Updated restored: ['10.1590/S0103-50532005000800025', ['Ibirama ,SC']]
# Original restored: ['10.1590/S0103-50532005000800026', ['Pantanal - MS, Brazil']]
# Performing FAISS search for: Pantanal - MS, Brazil
# Top result: Brasilandia ,MS
# Updated restored: ['10.1590/S0103-50532005000800026', ['Brasilandia ,MS']]
# Original restored: ['10.1590/S0103-50532005000800029', ['Araraquara, São Paulo, Brazil']]
# Performing FAISS search for: Araraquara, São Paulo, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1590/S0103-50532005000800029', ['Araraquara ,SP']]
# Original restored: ['10.1590/S0103-50532006000300017', ['São Carlos-SP, Brazil', 'Belém, Pará, Brazil']]
# Performing FAISS search for: São Carlos-SP, Brazil
# Top result: Sao Carlos ,SP
# Performing FAISS search for: Belém, Pará, Brazil
# Top result: Belem ,PA
# Updated restored: ['10.1590/S0103-50532006000300017', ['Sao Carlos ,SP', 'Belem ,PA']]
# Original restored: ['10.1590/S0103-50532007000700017', ['Estação Ecológica e Experimental de Mogi-Guaçu, São Paulo, Brazil']]
# Performing FAISS search for: Estação Ecológica e Experimental de Mogi-Guaçu, São Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1590/S0103-50532007000700017', ['Mogi Guacu ,SP']]
# Original restored: ['10.1590/s0100-40422008000700015', ['Not specified']]
# Performing FAISS search for: Not specified
# Top result: N/A,TO
# Updated restored: ['10.1590/s0100-40422008000700015', ['N/A,TO']]
# Original restored: ['10.3390/molecules15129205', ['São Paulo State, Brazil']]
# Performing FAISS search for: São Paulo State, Brazil
# Top result: Sao Paulo ,SP
# Updated restored: ['10.3390/molecules15129205', ['Sao Paulo ,SP']]
# Original restored: ['10.5935/0100-4042.20140049', ['Serra dos Pirineus, Pirenópolis - GO, Brazil']]
# Performing FAISS search for: Serra dos Pirineus, Pirenópolis - GO, Brazil
# Top result: Pirenopolis ,GO
# Updated restored: ['10.5935/0100-4042.20140049', ['Pirenopolis ,GO']]
# Finished processing file. Results saved to: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_1_3rd_processed.csv
# Processing file: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_8_1st.csv
# Original restored: ['10.1002/cbdv.200590016', []]
# Updated restored: ['10.1002/cbdv.200590016', []]
# Original restored: ['10.1002/cbdv.200800342', ['Parque Estadual Carlos Botelho, São Miguel Arcanjo, São Paulo, Brazil']]
# Performing FAISS search for: Parque Estadual Carlos Botelho, São Miguel Arcanjo, São Paulo, Brazil
# Top result: Sao Miguel Arcanjo ,SP
# Updated restored: ['10.1002/cbdv.200800342', ['Sao Miguel Arcanjo ,SP']]
# Original restored: ['10.1002/hlca.200890147', ['Apore, GO, Brazil']]
# Performing FAISS search for: Apore, GO, Brazil
# Top result: Apore ,GO
# Updated restored: ['10.1002/hlca.200890147', ['Apore ,GO']]
# Original restored: ['10.1002/jobm.200800093', ['Ribeirão Preto, State of São Paulo, Brazil']]
# Performing FAISS search for: Ribeirão Preto, State of São Paulo, Brazil
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1002/jobm.200800093', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1002/jobm.200800093', ['Ribeirão Preto, State of São Paulo, Brazil']]
# Performing FAISS search for: Ribeirão Preto, State of São Paulo, Brazil
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1002/jobm.200800093', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1002/ps.1278', ['Poços de Caldas, Minas Gerais, Brazil']]
# Performing FAISS search for: Poços de Caldas, Minas Gerais, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1002/ps.1278', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1002/ps.478', ['Rio Claro, São Paulo, Brazil']]
# Performing FAISS search for: Rio Claro, São Paulo, Brazil
# Top result: Rio Claro ,SP
# ...
# Original restored: ['10.1590/S0100-40422008000400018', ['Instituto de Botânica, São Paulo – SP']]
# Performing FAISS search for: Instituto de Botânica, São Paulo – SP
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1590/S0100-40422008000400018', ['Sao Paulo ,SP']]
# Original restored: ['10.1590/S0100-40422008000400023', ['Reserva da Juréia, Iguape – SP']]
# Performing FAISS search for: Reserva da Juréia, Iguape – SP
# Top result: Iguape ,SP
# Updated restored: ['10.1590/S0100-40422008000400023', ['Iguape ,SP']]
# Original restored: ['10.1590/S0100-40422009000600037', ["Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)"]]
# Performing FAISS search for: Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)
# Top result: Piracicaba ,SP
# Updated restored: ['10.1590/S0100-40422009000600037', ['Piracicaba ,SP']]
# Original restored: ['10.1590/S0100-40422010001000006', ['Araraquara – SP, Brazil']]
# Performing FAISS search for: Araraquara – SP, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1590/S0100-40422010001000006', ['Araraquara ,SP']]
# Original restored: ['10.1590/S0100-46702007000300002', ['Campus da Universidade de São Paulo (USP), Ribeirão Preto, São Paulo, Brasil']]
# Performing FAISS search for: Campus da Universidade de São Paulo (USP), Ribeirão Preto, São Paulo, Brasil
# Top result: Ribeirao Preto ,SP
# Updated restored: ['10.1590/S0100-46702007000300002', ['Ribeirao Preto ,SP']]
# Original restored: ['10.1590/S0102-695X2007000300003', ['Juréia Reserve, São Paulo, Brazil']]
# Performing FAISS search for: Juréia Reserve, São Paulo, Brazil
# Top result: Sao Paulo ,SP
# Updated restored: ['10.1590/S0102-695X2007000300003', ['Sao Paulo ,SP']]
# Original restored: ['10.1590/S0102-695X2008000200010', ['Lavras, State of Minas Gerais, Brazil']]
# Performing FAISS search for: Lavras, State of Minas Gerais, Brazil
# Top result: Lavras ,MG
# Updated restored: ['10.1590/S0102-695X2008000200010', ['Lavras ,MG']]
# Original restored: ['10.1590/S0102-695X2009000100002', ['Viçosa, Minas Gerais, Brazil']]
# Performing FAISS search for: Viçosa, Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1590/S0102-695X2009000100002', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1590/S0102-695X2010000100002', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1590/S0102-695X2010000100002', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1590/S0102-695X2010005000017', ['Botanic Garden of São Paulo, São Paulo, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, São Paulo, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1590/S0102-695X2010005000017', ['Jardinopolis ,SP']]
# Original restored: ['10.1590/S0102-695X2012005000106', []]
# Updated restored: ['10.1590/S0102-695X2012005000106', []]
# Original restored: ['10.1590/S0103-50532002000100010', ['Ressacada, Ibirama, SC, Brazil']]
# Performing FAISS search for: Ressacada, Ibirama, SC, Brazil
# Top result: Ibirama ,SC
# Updated restored: ['10.1590/S0103-50532002000100010', ['Ibirama ,SC']]
# Original restored: ['10.1590/S0103-50532002000100019', ['Rio Claro, São Paulo state, Brazil']]
# Performing FAISS search for: Rio Claro, São Paulo state, Brazil
# Top result: Rio Claro ,SP
# Updated restored: ['10.1590/S0103-50532002000100019', ['Rio Claro ,SP']]
# Original restored: ['10.1590/S0103-50532003000300007', ['Bahia, Brazil', 'Brazil']]
# Performing FAISS search for: Bahia, Brazil
# Top result: Pirai Do Norte ,BA
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1590/S0103-50532003000300007', ['Pirai Do Norte ,BA', 'Brasilandia Do Sul ,PR']]
# Original restored: ['10.1590/S0103-50532003000500012', ['Reserva do Viro, Belém - PA, Brazil']]
# Performing FAISS search for: Reserva do Viro, Belém - PA, Brazil
# Top result: Brasil Novo ,PA
# Updated restored: ['10.1590/S0103-50532003000500012', ['Brasil Novo ,PA']]
# Original restored: ['10.1590/S0103-50532005000400005', ['Atlantic Forest, Brazil']]
# Performing FAISS search for: Atlantic Forest, Brazil
# Top result: Floresta Do Araguaia ,PA
# Updated restored: ['10.1590/S0103-50532005000400005', ['Floresta Do Araguaia ,PA']]
# Original restored: ['10.1590/S0103-50532005000400031', ['Brazil']]
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1590/S0103-50532005000400031', ['Brasilandia Do Sul ,PR']]
# Original restored: ['10.1590/S0103-50532005000800008', ['Belém, Pará State, Brazil']]
# Performing FAISS search for: Belém, Pará State, Brazil
# Top result: Belem ,PB
# Updated restored: ['10.1590/S0103-50532005000800008', ['Belem ,PB']]
# Original restored: ['10.1590/S0103-50532005000800018', ['Institute of Chemistry (UNESP) in Araraquara, Brazil and Institute of Biological Chemistry (WSU) in Pullman, USA.']]
# Performing FAISS search for: Institute of Chemistry (UNESP) in Araraquara, Brazil and Institute of Biological Chemistry (WSU) in Pullman, USA.
# Top result: Campinas ,SP
# Updated restored: ['10.1590/S0103-50532005000800018', ['Campinas ,SP']]
# Original restored: ['10.1590/S0103-50532005000800025', ['Ressacada, Ibirama, SC, Brazil']]
# Performing FAISS search for: Ressacada, Ibirama, SC, Brazil
# Top result: Ibirama ,SC
# Updated restored: ['10.1590/S0103-50532005000800025', ['Ibirama ,SC']]
# Original restored: ['10.1590/S0103-50532005000800026', ['Pantanal - MS, Brazil']]
# Performing FAISS search for: Pantanal - MS, Brazil
# Top result: Brasilandia ,MS
# Updated restored: ['10.1590/S0103-50532005000800026', ['Brasilandia ,MS']]
# Original restored: ['10.1590/S0103-50532005000800029', ['Araraquara, São Paulo, Brazil']]
# Performing FAISS search for: Araraquara, São Paulo, Brazil
# Top result: Araraquara ,SP
# Updated restored: ['10.1590/S0103-50532005000800029', ['Araraquara ,SP']]
# Original restored: ['10.1590/S0103-50532006000300017', ['São Carlos-SP, Brazil', 'Belém, Pará, Brazil']]
# Performing FAISS search for: São Carlos-SP, Brazil
# Top result: Sao Carlos ,SP
# Performing FAISS search for: Belém, Pará, Brazil
# Top result: Belem ,PA
# Updated restored: ['10.1590/S0103-50532006000300017', ['Sao Carlos ,SP', 'Belem ,PA']]
# Original restored: ['10.1590/S0103-50532006000300017', ['São Carlos-SP, Brazil', 'Belém, Pará, Brazil']]
# Performing FAISS search for: São Carlos-SP, Brazil
# Top result: Sao Carlos ,SP
# Performing FAISS search for: Belém, Pará, Brazil
# Top result: Belem ,PA
# Updated restored: ['10.1590/S0103-50532006000300017', ['Sao Carlos ,SP', 'Belem ,PA']]
# Original restored: ['10.1590/S0103-50532009000100029', []]
# Updated restored: ['10.1590/S0103-50532009000100029', []]
# Original restored: ['10.1590/S0103-50532009000400008', ['Campinas (SP) at the Instituto Agronômico de Campinas']]
# Performing FAISS search for: Campinas (SP) at the Instituto Agronômico de Campinas
# Top result: Campinas ,SP
# Updated restored: ['10.1590/S0103-50532009000400008', ['Campinas ,SP']]
# Original restored: ['10.1590/S0103-50532010000500016', ['Rio Verde-Jataí, GO, Brazil']]
# Performing FAISS search for: Rio Verde-Jataí, GO, Brazil
# Top result: Rio Verde ,GO
# Updated restored: ['10.1590/S0103-50532010000500016', ['Rio Verde ,GO']]
# Original restored: ['10.1590/s0100-40422008000700015', ['Not specified']]
# Performing FAISS search for: Not specified
# Top result: N/A,TO
# Updated restored: ['10.1590/s0100-40422008000700015', ['N/A,TO']]
# Original restored: ['10.2174/187152010794728620', ['not specified', 'Federal University of Viçosa, MG, Brazil', 'Belém, Pará State, Brazil']]
# Performing FAISS search for: not specified
# Top result: N/A,TO
# Performing FAISS search for: Federal University of Viçosa, MG, Brazil
# Top result: Santa Vitoria ,MG
# Performing FAISS search for: Belém, Pará State, Brazil
# Top result: Belem ,PB
# Updated restored: ['10.2174/187152010794728620', ['N/A,TO', 'Santa Vitoria ,MG', 'Belem ,PB']]
# Original restored: ['10.3390/molecules190812031', ['Amazon state, Brazil']]
# Performing FAISS search for: Amazon state, Brazil
# Top result: Porto Amazonas ,PR
# Updated restored: ['10.3390/molecules190812031', ['Porto Amazonas ,PR']]
# Original restored: ['10.4067/S0717-97072009000300004', ['Botanic Garden of São Paulo, São Paulo State, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, São Paulo State, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.4067/S0717-97072009000300004', ['Jardinopolis ,SP']]
# Original restored: ['10.5935/0100-4042.20140049', ['Serra dos Pirineus, Pirenópolis - GO, Brazil']]
# Performing FAISS search for: Serra dos Pirineus, Pirenópolis - GO, Brazil
# Top result: Pirenopolis ,GO
# Updated restored: ['10.5935/0100-4042.20140049', ['Pirenopolis ,GO']]
# Original restored: ['10.5935/0103-5053.19930018', []]
# Updated restored: ['10.5935/0103-5053.19930018', []]
# Finished processing file. Results saved to: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_4_1st_processed.csv
# Processing file: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_9_4th.csv
# Original restored: ['10.1002/hlca.200890147', ['Apore, GO, Brazil']]
# Performing FAISS search for: Apore, GO, Brazil
# Top result: Apore ,GO
# Updated restored: ['10.1002/hlca.200890147', ['Apore ,GO']]
# Original restored: ['10.1016/S0031-9422(03)00153-5', ['Manaus, Brazil']]
# Performing FAISS search for: Manaus, Brazil
# Top result: Manaus ,AM
# Updated restored: ['10.1016/S0031-9422(03)00153-5', ['Manaus ,AM']]
# Original restored: ['10.1016/S0031-9422(97)00598-0', ['São Carlos, SP, Brazil']]
# Performing FAISS search for: São Carlos, SP, Brazil
# Top result: Sao Carlos ,SP
# Updated restored: ['10.1016/S0031-9422(97)00598-0', ['Sao Carlos ,SP']]
# Original restored: ['10.1016/j.chroma.2009.02.066', ['Estação Experimental de Citricultura do Instituto Agronômico de Campinas, Cordeirópolis, Brazil']]
# Performing FAISS search for: Estação Experimental de Citricultura do Instituto Agronômico de Campinas, Cordeirópolis, Brazil
# Top result: Campinas ,SP
# Updated restored: ['10.1016/j.chroma.2009.02.066', ['Campinas ,SP']]
# Original restored: ['10.1016/j.jep.2007.09.020', ['Poços de Caldas, Minas Gerais State, Brazil']]
# Performing FAISS search for: Poços de Caldas, Minas Gerais State, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1016/j.jep.2007.09.020', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1016/j.jpba.2012.08.028', []]
# Updated restored: ['10.1016/j.jpba.2012.08.028', []]
# Original restored: ['10.1016/j.phytochem.2007.08.012', ['Ibate – SP, Brazil']]
# Performing FAISS search for: Ibate – SP, Brazil
# Top result: Ibate ,SP
# Updated restored: ['10.1016/j.phytochem.2007.08.012', ['Ibate ,SP']]
# Original restored: ['10.1016/j.phytol.2010.11.003', ['Mogi-Guacu, Sao Paulo, Brazil']]
# Performing FAISS search for: Mogi-Guacu, Sao Paulo, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1016/j.phytol.2010.11.003', ['Mogi Guacu ,SP']]
# Original restored: ['10.1016/j.tiv.2008.01.003', ["Extracted from the dried and powdered root bark of M. ilicifolia'"]]
# Performing FAISS search for: Extracted from the dried and powdered root bark of M. ilicifolia'
# Top result: Ilicinea ,MG
# Updated restored: ['10.1016/j.tiv.2008.01.003', ['Ilicinea ,MG']]
# Original restored: ['10.1021/jf100233y', ['Biological Reserve and Experimental Station at Mogi Guaçu, São Paulo State, Brazil']]
# Performing FAISS search for: Biological Reserve and Experimental Station at Mogi Guaçu, São Paulo State, Brazil
# Top result: Mogi Guacu ,SP
# Updated restored: ['10.1021/jf100233y', ['Mogi Guacu ,SP']]
# Original restored: ['10.1021/np049863m', ['Reserva do Virá, Belém, PA, Brazil']]
# Performing FAISS search for: Reserva do Virá, Belém, PA, Brazil
# Top result: Belem ,PB
# Updated restored: ['10.1021/np049863m', ['Belem ,PB']]
# Original restored: ['10.1021/np4006822', ['Federal University of Pernambuco, Brazil']]
# Performing FAISS search for: Federal University of Pernambuco, Brazil
# Top result: Recife ,PE
# Updated restored: ['10.1021/np4006822', ['Recife ,PE']]
# Original restored: ['10.1021/np800612x', ['Botanic Garden of São Paulo, São Paulo State, Brazil']]
# Performing FAISS search for: Botanic Garden of São Paulo, São Paulo State, Brazil
# Top result: Jardinopolis ,SP
# Updated restored: ['10.1021/np800612x', ['Jardinopolis ,SP']]
# Original restored: ['10.1055/s-0029-1185364', ['Poços de Caldas, MG, Brazil']]
# Performing FAISS search for: Poços de Caldas, MG, Brazil
# Top result: Pocos De Caldas ,MG
# Updated restored: ['10.1055/s-0029-1185364', ['Pocos De Caldas ,MG']]
# Original restored: ['10.1080/14786419.2011.647020', ['Minas Gerais, Brazil']]
# Performing FAISS search for: Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1080/14786419.2011.647020', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1093/mutage/gep034', ['Parque Estadual Carlos Botelho (São Miguel Arcanjo, São Paulo, Brazil)']]
# Performing FAISS search for: Parque Estadual Carlos Botelho (São Miguel Arcanjo, São Paulo, Brazil)
# Top result: Sao Miguel Arcanjo ,SP
# Updated restored: ['10.1093/mutage/gep034', ['Sao Miguel Arcanjo ,SP']]
# Original restored: ['10.1590/S0073-47212009000100009', []]
# Updated restored: ['10.1590/S0073-47212009000100009', []]
# Original restored: ['10.1590/S0100-40422005000400009', ['Estação Ecológica de Itirapina, Itirapina – SP, Brazil']]
# Performing FAISS search for: Estação Ecológica de Itirapina, Itirapina – SP, Brazil
# Top result: Itirapua ,SP
# Updated restored: ['10.1590/S0100-40422005000400009', ['Itirapua ,SP']]
# Original restored: ['10.1590/S0100-40422008000400023', ['Reserva da Juréia, Iguape – SP']]
# Performing FAISS search for: Reserva da Juréia, Iguape – SP
# Top result: Iguape ,SP
# Updated restored: ['10.1590/S0100-40422008000400023', ['Iguape ,SP']]
# Original restored: ['10.1590/S0100-40422009000600037', ["Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)"]]
# Performing FAISS search for: Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz' (Esalq/USP)
# Top result: Piracicaba ,SP
# Updated restored: ['10.1590/S0100-40422009000600037', ['Piracicaba ,SP']]
# Original restored: ['10.1590/S0100-40422010000900005', ["Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz'/USP"]]
# Performing FAISS search for: Piracicaba/SP, Campus da Escola Superior de Agricultura 'Luiz de Queiroz'/USP
# Top result: Piracicaba ,SP
# Updated restored: ['10.1590/S0100-40422010000900005', ['Piracicaba ,SP']]
# Original restored: ['10.1590/S0102-695X2008000200010', ['Lavras, State of Minas Gerais, Brazil']]
# Performing FAISS search for: Lavras, State of Minas Gerais, Brazil
# Top result: Lavras ,MG
# Updated restored: ['10.1590/S0102-695X2008000200010', ['Lavras ,MG']]
# Original restored: ['10.1590/S0102-695X2009000100002', ['Viçosa, Minas Gerais, Brazil']]
# Performing FAISS search for: Viçosa, Minas Gerais, Brazil
# Top result: Brasilandia De Minas ,MG
# Updated restored: ['10.1590/S0102-695X2009000100002', ['Brasilandia De Minas ,MG']]
# Original restored: ['10.1590/S0103-50532003000300007', ['Bahia, Brazil', 'Brazil']]
# Performing FAISS search for: Bahia, Brazil
# Top result: Pirai Do Norte ,BA
# Performing FAISS search for: Brazil
# Top result: Brasilandia Do Sul ,PR
# Updated restored: ['10.1590/S0103-50532003000300007', ['Pirai Do Norte ,BA', 'Brasilandia Do Sul ,PR']]
# Original restored: ['10.1590/S0103-50532005000800008', ['Belém, Pará State, Brazil']]
# Performing FAISS search for: Belém, Pará State, Brazil
# Top result: Belem ,PB
# Updated restored: ['10.1590/S0103-50532005000800008', ['Belem ,PB']]
# Original restored: ['10.1590/S1519-566X2008000600013', []]
# Updated restored: ['10.1590/S1519-566X2008000600013', []]
# Original restored: ['10.5935/0100-4042.20140049', ['Serra dos Pirineus, Pirenópolis - GO, Brazil']]
# Performing FAISS search for: Serra dos Pirineus, Pirenópolis - GO, Brazil
# Top result: Pirenopolis ,GO
# Updated restored: ['10.5935/0100-4042.20140049', ['Pirenopolis ,GO']]
# Finished processing file. Results saved to: results/LLM_enhanced/llm_results_gpt4_0.8_doi_collectionSite_9_4th_processed.csv
